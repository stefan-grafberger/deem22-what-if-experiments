# %%
from product_images_shapley_naive import print_legend, do_shapley_value_naive, measure_shapley_naive_exec_time
from whatif.example_pipelines.product_images_shapley_opt import measure_shapley_opt_exec_time, do_shapley_value_opt
from whatif.example_pipelines.product_images_shapley_qualitative import do_shapley_value_qualitative
print_legend()
# Out:
# iteration: In each iteration, we execute the pipeline and clean #cleaning_batch_size rows afterwards, either using shapley values or random sampling. Param for this: $use_shapley_weighting
# already_cleaned_rows: Already cleaned rows
# total_corrupted_rows: Total corrupted rows
# false_corruption_alarm: False alarms in that iteration for #rows that were not corrupted
# correct_corruption_alarm: Correct alarms in that iteration for #rows that were corrupted
# corruption_not_detected_yet: In that and previous iterations, there were corrupted #rows not discover yet
# fraction_data_cleaned: fraction of corrupted data that was cleaned already
# model_score: Model score on current data with potential left-over corruptions

# %%
do_shapley_value_qualitative(0.5, 10, True, 10, 50)
# Out:
# Starting iteration 0 now...
# 30/30 [==============================] - 1s 23ms/step - loss: 0.7060 - accuracy: 0.4756
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7012 - accuracy: 0.4016
# Starting iteration 1 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.6938 - accuracy: 0.5392
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6620 - accuracy: 0.7500
# Starting iteration 2 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.7050 - accuracy: 0.5159
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6559 - accuracy: 0.6762
# Starting iteration 3 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.6637 - accuracy: 0.6282
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5315 - accuracy: 0.8893
# Starting iteration 4 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.6205 - accuracy: 0.6822
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5145 - accuracy: 0.8402
# Starting iteration 5 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.5818 - accuracy: 0.7097
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4444 - accuracy: 0.9303
# Starting iteration 6 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.5398 - accuracy: 0.7627
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4040 - accuracy: 0.9098
# Starting iteration 7 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.4722 - accuracy: 0.8051
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3846 - accuracy: 0.9262
# Starting iteration 8 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.4006 - accuracy: 0.8347
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3049 - accuracy: 0.8975
# Starting iteration 9 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3450 - accuracy: 0.8729
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2213 - accuracy: 0.9180
# Done!
# 2022-02-17 13:54:07.685813: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-17 13:54:07.776372: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
#    iteration  already_cleaned_rows  total_corrupted_rows  \
# 0          0                     0                   472
# 1          1                    50                   472
# 2          2                   100                   472
# 3          3                   150                   472
# 4          4                   198                   472
# 5          5                   245                   472
# 6          6                   290                   472
# 7          7                   332                   472
# 8          8                   371                   472
# 9          9                   403                   472
#
#    false_corruption_alarm  correct_corruption_alarm  \
# 0                       0                        50
# 1                       0                        50
# 2                       0                        50
# 3                       2                        48
# 4                       3                        47
# 5                       5                        45
# 6                       8                        42
# 7                      11                        39
# 8                      18                        32
# 9                      28                        22
#
#    corruption_not_detected_yet  fraction_data_cleaned  model_score
# 0                          422               0.105932     0.401639
# 1                          372               0.211864     0.750000
# 2                          322               0.317797     0.676230
# 3                          274               0.419492     0.889344
# 4                          227               0.519068     0.840164
# 5                          182               0.614407     0.930328
# 6                          140               0.703390     0.909836
# 7                          101               0.786017     0.926230
# 8                           69               0.853814     0.897541
# 9                           47               0.900424     0.918033

# %%
do_shapley_value_qualitative(0.5, 10, False, 10, 50)
# Out:
# Starting iteration 0 now...
# 31/31 [==============================] - 1s 19ms/step - loss: 0.7029 - accuracy: 0.4907
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6863 - accuracy: 0.6875
# Starting iteration 1 now...
# 31/31 [==============================] - 1s 19ms/step - loss: 0.7031 - accuracy: 0.5062
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6704 - accuracy: 0.8750
# Starting iteration 2 now...
# 31/31 [==============================] - 1s 19ms/step - loss: 0.6956 - accuracy: 0.5239
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6414 - accuracy: 0.8929
# Starting iteration 3 now...
# 31/31 [==============================] - 1s 19ms/step - loss: 0.6975 - accuracy: 0.5332
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6780 - accuracy: 0.5089
# Starting iteration 4 now...
# 31/31 [==============================] - 1s 19ms/step - loss: 0.6948 - accuracy: 0.5322
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6536 - accuracy: 0.8170
# Starting iteration 5 now...
# 31/31 [==============================] - 1s 19ms/step - loss: 0.6901 - accuracy: 0.5695
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6338 - accuracy: 0.8616
# Starting iteration 6 now...
# 31/31 [==============================] - 1s 19ms/step - loss: 0.6859 - accuracy: 0.5695
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6439 - accuracy: 0.7545
# Starting iteration 7 now...
# 31/31 [==============================] - 1s 19ms/step - loss: 0.6881 - accuracy: 0.5726
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6254 - accuracy: 0.8884
# Starting iteration 8 now...
# 31/31 [==============================] - 1s 20ms/step - loss: 0.6769 - accuracy: 0.5851
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6172 - accuracy: 0.8973
# Starting iteration 9 now...
# 31/31 [==============================] - 1s 19ms/step - loss: 0.6769 - accuracy: 0.5996
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5452 - accuracy: 0.9018
# Done!
#    iteration  already_cleaned_rows  total_corrupted_rows  \
# 0          0                     0                   482
# 1          1                    29                   482
# 2          2                    49                   482
# 3          3                    70                   482
# 4          4                    88                   482
# 5          5                   109                   482
# 6          6                   129                   482
# 7          7                   147                   482
# 8          8                   161                   482
# 9          9                   175                   482
#
#    false_corruption_alarm  correct_corruption_alarm  \
# 0                      21                        29
# 1                      30                        20
# 2                      29                        21
# 3                      32                        18
# 4                      29                        21
# 5                      30                        20
# 6                      32                        18
# 7                      36                        14
# 8                      36                        14
# 9                      31                        19
#
#    corruption_not_detected_yet  fraction_data_cleaned  model_score
# 0                          453               0.060166     0.687500
# 1                          433               0.101660     0.875000
# 2                          412               0.145228     0.892857
# 3                          394               0.182573     0.508929
# 4                          373               0.226141     0.816964
# 5                          353               0.267635     0.861607
# 6                          335               0.304979     0.754464
# 7                          321               0.334025     0.888393
# 8                          307               0.363071     0.897321
# 9                          288               0.402490     0.901786

# %%
measure_shapley_naive_exec_time(0.2, 10, True, 10, 50, True, 3)
# Out:
# Starting iteration 0 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.5794 - accuracy: 0.7158
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5709 - accuracy: 0.7395
# Starting iteration 1 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.5490 - accuracy: 0.7495
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5418 - accuracy: 0.7815
# Starting iteration 2 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.5035 - accuracy: 0.7768
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4732 - accuracy: 0.8613
# Starting iteration 3 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.4310 - accuracy: 0.8242
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3536 - accuracy: 0.9034
# Starting iteration 4 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3624 - accuracy: 0.8611
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2663 - accuracy: 0.8992
# Starting iteration 5 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3334 - accuracy: 0.8474
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2044 - accuracy: 0.9328
# Starting iteration 6 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.2910 - accuracy: 0.8884
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2192 - accuracy: 0.9160
# Starting iteration 7 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.2716 - accuracy: 0.9000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2143 - accuracy: 0.9160
# Starting iteration 8 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3480 - accuracy: 0.8305
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2269 - accuracy: 0.8950
# Starting iteration 9 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3261 - accuracy: 0.8432
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2471 - accuracy: 0.8992
# Done!
# Starting iteration 0 now...
# 30/30 [==============================] - 1s 23ms/step - loss: 0.5889 - accuracy: 0.7211
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5683 - accuracy: 0.7395
# Starting iteration 1 now...
# 30/30 [==============================] - 1s 23ms/step - loss: 0.5591 - accuracy: 0.7442
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5002 - accuracy: 0.8319
# Starting iteration 2 now...
# 30/30 [==============================] - 1s 24ms/step - loss: 0.4872 - accuracy: 0.8032
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4674 - accuracy: 0.8025
# Starting iteration 3 now...
# 30/30 [==============================] - 2s 46ms/step - loss: 0.4268 - accuracy: 0.8411
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4058 - accuracy: 0.8445
# Starting iteration 4 now...
# 30/30 [==============================] - 2s 31ms/step - loss: 0.4046 - accuracy: 0.8453
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4038 - accuracy: 0.8403
# Starting iteration 5 now...
# 30/30 [==============================] - 1s 24ms/step - loss: 0.3385 - accuracy: 0.8705
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3090 - accuracy: 0.8697
# Starting iteration 6 now...
# 30/30 [==============================] - 1s 24ms/step - loss: 0.2955 - accuracy: 0.8863
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2857 - accuracy: 0.8992
# Starting iteration 7 now...
# 30/30 [==============================] - 1s 24ms/step - loss: 0.2964 - accuracy: 0.8863
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2525 - accuracy: 0.9118
# Starting iteration 8 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3203 - accuracy: 0.8811
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2224 - accuracy: 0.9202
# Starting iteration 9 now...
# 30/30 [==============================] - 1s 27ms/step - loss: 0.3215 - accuracy: 0.8705
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1897 - accuracy: 0.9286
# Done!
# Starting iteration 0 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.6175 - accuracy: 0.6937
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5852 - accuracy: 0.7437
# Starting iteration 1 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.5946 - accuracy: 0.7379
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5331 - accuracy: 0.7899
# Starting iteration 2 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.5059 - accuracy: 0.7937
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4756 - accuracy: 0.8277
# Starting iteration 3 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.4437 - accuracy: 0.8263
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4020 - accuracy: 0.8487
# Starting iteration 4 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3628 - accuracy: 0.8642
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3196 - accuracy: 0.9034
# Starting iteration 5 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3456 - accuracy: 0.8747
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2626 - accuracy: 0.8992
# Starting iteration 6 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3076 - accuracy: 0.8726
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1984 - accuracy: 0.9076
# Starting iteration 7 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3044 - accuracy: 0.8968
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2469 - accuracy: 0.8992
# Starting iteration 8 now...
# 30/30 [==============================] - 1s 22ms/step - loss: 0.3230 - accuracy: 0.8537
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2417 - accuracy: 0.9076
# Starting iteration 9 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3121 - accuracy: 0.8768
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2047 - accuracy: 0.9034
# Done!
#     runtimes
# 0  21.307941
# 1  29.560178
# 2  22.271339

# %%
measure_shapley_naive_exec_time(0.2, 10, True, 10, 50, False, 3)
# Out:
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
#     runtimes
# 0  11.319755
# 1  10.896126
# 2  10.719960

# %%
measure_shapley_opt_exec_time(0.2, 10, True, 10, 50, True, 3)
# Out:
# Starting iteration 0 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.5913 - accuracy: 0.7179
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5887 - accuracy: 0.7647
# Starting iteration 1 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.5381 - accuracy: 0.7663
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5752 - accuracy: 0.7521
# Starting iteration 2 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.4512 - accuracy: 0.8347
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5342 - accuracy: 0.7647
# Starting iteration 3 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3728 - accuracy: 0.8463
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5794 - accuracy: 0.7521
# Starting iteration 4 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3090 - accuracy: 0.8663
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7198 - accuracy: 0.7605
# Starting iteration 5 now...
# 30/30 [==============================] - 1s 22ms/step - loss: 0.3336 - accuracy: 0.8505
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7598 - accuracy: 0.7563
# Starting iteration 6 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3403 - accuracy: 0.8389
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7833 - accuracy: 0.7605
# Starting iteration 7 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3032 - accuracy: 0.8695
# 8/8 [==============================] - 0s 7ms/step - loss: 0.7952 - accuracy: 0.7605
# Starting iteration 8 now...
# 30/30 [==============================] - 1s 24ms/step - loss: 0.2922 - accuracy: 0.8895
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7618 - accuracy: 0.7605
# Starting iteration 9 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2747 - accuracy: 0.8874
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7635 - accuracy: 0.7563
# Done!
# Starting iteration 0 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.5964 - accuracy: 0.7253
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5961 - accuracy: 0.7311
# Starting iteration 1 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.5047 - accuracy: 0.7789
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5740 - accuracy: 0.7353
# Starting iteration 2 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.4362 - accuracy: 0.8232
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5907 - accuracy: 0.7437
# Starting iteration 3 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3557 - accuracy: 0.8611
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7537 - accuracy: 0.7269
# Starting iteration 4 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3134 - accuracy: 0.8674
# 8/8 [==============================] - 0s 6ms/step - loss: 0.8407 - accuracy: 0.7311
# Starting iteration 5 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2910 - accuracy: 0.8747
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0408 - accuracy: 0.7395
# Starting iteration 6 now...
# 30/30 [==============================] - 1s 24ms/step - loss: 0.3041 - accuracy: 0.8874
# 8/8 [==============================] - 0s 5ms/step - loss: 1.1280 - accuracy: 0.7395
# Starting iteration 7 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2971 - accuracy: 0.8874
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0137 - accuracy: 0.7227
# Starting iteration 8 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2751 - accuracy: 0.8926
# 8/8 [==============================] - 0s 6ms/step - loss: 1.0052 - accuracy: 0.7269
# Starting iteration 9 now...
# 30/30 [==============================] - 1s 24ms/step - loss: 0.2896 - accuracy: 0.8800
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9980 - accuracy: 0.7353
# Done!
# Starting iteration 0 now...
# 30/30 [==============================] - 1s 25ms/step - loss: 0.5830 - accuracy: 0.7242
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5567 - accuracy: 0.7605
# Starting iteration 1 now...
# 30/30 [==============================] - 1s 25ms/step - loss: 0.5370 - accuracy: 0.7421
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5464 - accuracy: 0.7479
# Starting iteration 2 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.4297 - accuracy: 0.8158
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5236 - accuracy: 0.7479
# Starting iteration 3 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3630 - accuracy: 0.8474
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5434 - accuracy: 0.7605
# Starting iteration 4 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3257 - accuracy: 0.8705
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6252 - accuracy: 0.7395
# Starting iteration 5 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3220 - accuracy: 0.8716
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6167 - accuracy: 0.7647
# Starting iteration 6 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2951 - accuracy: 0.8895
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6738 - accuracy: 0.7563
# Starting iteration 7 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3092 - accuracy: 0.8758
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6201 - accuracy: 0.7647
# Starting iteration 8 now...
# 30/30 [==============================] - 1s 22ms/step - loss: 0.2746 - accuracy: 0.9021
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7151 - accuracy: 0.7647
# Starting iteration 9 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2825 - accuracy: 0.8926
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6702 - accuracy: 0.7479
# Done!
#     runtimes
# 0  13.367961
# 1  13.438962
# 2  14.189090

# %%
measure_shapley_opt_exec_time(0.2, 10, True, 10, 50, False, 3)
# Out:
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
#    runtimes
# 0  2.051879
# 1  2.024736
# 2  2.087346

# %%
do_shapley_value_opt(0.2, 10, True, 10, 50, True)
# Out:
# Starting iteration 0 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.5833 - accuracy: 0.7379
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5848 - accuracy: 0.7311
# 2022-02-17 14:15:43.470538: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-17 14:15:43.555578: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/1x/7tjtf92157d00yflbr4s67f80000gn/T/ipykernel_3948/3399223353.py in <module>
# ----> 1 do_shapley_value_opt(0.2, 10, True, 10, 50, True)
#
# ~/Documents/deem-what-if-experiments/whatif/example_pipelines/product_images_shapley_opt.py in do_shapley_value_opt(corruption_fraction, num_iterations, use_shapley_weighting, shapley_value_k, cleaning_batch_size, do_model_train_and_score)
#     258     corrupted_row_ids = create_corrupt_data(corruption_fraction)
#     259
# --> 260     iteration_results = execute_image_pipeline_w_shapley_opt(corrupted_row_ids,
#     261                                                              use_shapley_weighting,
#     262                                                              shapley_value_k,
#
# ~/Documents/deem-what-if-experiments/whatif/example_pipelines/product_images_shapley_opt.py in execute_image_pipeline_w_shapley_opt(corrupted_row_ids, shapley_value_cleaning, shapley_value_k, cleaning_batch_size, do_model_train_and_score, num_iterations)
#      90
#      91     # Cleaning start
# ---> 92     iteration_results = cleaning_with_maybe_model_training(cleaning_batch_size, corrupted_row_ids,
#      93                                                            do_model_train_and_score,
#      94                                                            train_image_lineage_ids,
#
# ~/Documents/deem-what-if-experiments/whatif/example_pipelines/product_images_shapley_opt.py in cleaning_with_maybe_model_training(cleaning_batch_size, corrupted_row_ids, do_model_train_and_score, train_image_lineage_ids, test_image_lineage_ids, model_without_pipeline, num_iterations, shapley_value_cleaning, shapley_value_k, train, x_test, x_train, y_test, y_train)
#     145                                                                      train_image_lineage_ids)
#     146         # TODO: Redo train test split, continue and make sure this works
# --> 147         train_df_for_resplit = pd.DataFrame({'x': x_train, 'y': y_train_squeezed, 'image_lineage_id': train_image_lineage_ids})
#     148         test_df_for_resplit = pd.DataFrame({'x': x_test, 'y': y_test_squeezed, 'image_lineage_id': test_image_lineage_ids})
#     149         big_df_for_resplit = pd.concat(train_df_for_resplit, test_df_for_resplit)
#
# ~/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ~/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      83
#      84         # don't force copy because getting jammed in an ndarray anyway
# ---> 85         arrays = _homogenize(arrays, index, dtype)
#      86
#      87         columns = ensure_index(columns)
#
# ~/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/pandas/core/internals/construction.py in _homogenize(data, index, dtype)
#     353                     val = dict(val)
#     354                 val = lib.fast_multiget(val, oindex._values, default=np.nan)
# --> 355             val = sanitize_array(
#     356                 val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     357             )
#
# ~/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     527     elif subarr.ndim > 1:
#     528         if isinstance(data, np.ndarray):
# --> 529             raise ValueError("Data must be 1-dimensional")
#     530         else:
#     531             subarr = com.asarray_tuplesafe(data, dtype=dtype)
#
# ValueError: Data must be 1-dimensional

# %%
do_shapley_value_opt(0.2, 10, True, 10, 50, False)
# Out:
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
#    iteration  already_cleaned_rows  total_corrupted_rows  \
# 0          0                     0                   238
# 1          1                    50                   238
# 2          2                    95                   238
# 3          3                   127                   238
# 4          4                   149                   238
# 5          5                   160                   238
# 6          6                   163                   238
# 7          7                   163                   238
# 8          8                   163                   238
# 9          9                   163                   238
#
#    false_corruption_alarm  correct_corruption_alarm  \
# 0                       0                        50
# 1                       5                        45
# 2                      18                        32
# 3                      28                        22
# 4                      39                        11
# 5                      47                         3
# 6                      50                         0
# 7                      50                         0
# 8                      50                         0
# 9                      50                         0
#
#    corruption_not_detected_yet  fraction_data_cleaned model_score
# 0                          188               0.210084        None
# 1                          143               0.399160        None
# 2                          111               0.533613        None
# 3                           89               0.626050        None
# 4                           78               0.672269        None
# 5                           75               0.684874        None
# 6                           75               0.684874        None
# 7                           75               0.684874        None
# 8                           75               0.684874        None
# 9                           75               0.684874        None

# %%
do_shapley_value_naive(0.2, 10, True, 10, 50, True)
# Out:
# Starting iteration 0 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.5932 - accuracy: 0.7158
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5693 - accuracy: 0.7521
# Starting iteration 1 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.5618 - accuracy: 0.7537
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5568 - accuracy: 0.7983
# Starting iteration 2 now...
# 30/30 [==============================] - 1s 24ms/step - loss: 0.4941 - accuracy: 0.7800
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4802 - accuracy: 0.8193
# Starting iteration 3 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.4321 - accuracy: 0.8326
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3968 - accuracy: 0.8697
# Starting iteration 4 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3871 - accuracy: 0.8484
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3340 - accuracy: 0.8866
# Starting iteration 5 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3410 - accuracy: 0.8653
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2225 - accuracy: 0.9244
# Starting iteration 6 now...
# 30/30 [==============================] - 1s 22ms/step - loss: 0.2973 - accuracy: 0.8821
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2344 - accuracy: 0.9034
# Starting iteration 7 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2965 - accuracy: 0.8947
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2227 - accuracy: 0.8908
# Starting iteration 8 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.3222 - accuracy: 0.8779
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2338 - accuracy: 0.8992
# Starting iteration 9 now...
# 30/30 [==============================] - 1s 22ms/step - loss: 0.2982 - accuracy: 0.8874
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2045 - accuracy: 0.9244
# Done!
# 2022-02-17 13:59:47.644090: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-17 13:59:47.710633: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
#    iteration  already_cleaned_rows  total_corrupted_rows  \
# 0          0                     0                   238
# 1          1                    50                   238
# 2          2                    99                   238
# 3          3                   142                   238
# 4          4                   177                   238
# 5          5                   201                   238
# 6          6                   214                   238
# 7          7                   217                   238
# 8          8                   218                   238
# 9          9                   219                   238
#
#    false_corruption_alarm  correct_corruption_alarm  \
# 0                       0                        50
# 1                       1                        49
# 2                       7                        43
# 3                      15                        35
# 4                      26                        24
# 5                      37                        13
# 6                      47                         3
# 7                      49                         1
# 8                      49                         1
# 9                      50                         0
#
#    corruption_not_detected_yet  fraction_data_cleaned  model_score
# 0                          188               0.210084     0.752101
# 1                          139               0.415966     0.798319
# 2                           96               0.596639     0.819328
# 3                           61               0.743697     0.869748
# 4                           37               0.844538     0.886555
# 5                           24               0.899160     0.924370
# 6                           21               0.911765     0.903361
# 7                           20               0.915966     0.890756
# 8                           19               0.920168     0.899160
# 9                           19               0.920168     0.924370
