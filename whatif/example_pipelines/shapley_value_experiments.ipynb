# %%
from product_images_shapley_naive import print_legend, do_shapley_value_naive, measure_shapley_naive_exec_time
from whatif.example_pipelines.product_images_shapley_opt import measure_shapley_opt_exec_time
print_legend()
# Out:
# iteration: In each iteration, we execute the pipeline and clean #cleaning_batch_size rows afterwards, either using shapley values or random sampling. Param for this: $use_shapley_weighting
# already_cleaned_rows: Already cleaned rows
# total_corrupted_rows: Total corrupted rows
# false_corruption_alarm: False alarms in that iteration for #rows that were not corrupted
# correct_corruption_alarm: Correct alarms in that iteration for #rows that were corrupted
# corruption_not_detected_yet: In that and previous iterations, there were corrupted #rows not discover yet
# fraction_data_cleaned: fraction of corrupted data that was cleaned already
# model_score: Model score on current data with potential left-over corruptions

# %%
do_shapley_value_naive(0.2, 10, True, 10, 50)
# Out:
# Starting iteration 0 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5879 - accuracy: 0.7395
# Starting iteration 1 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5709 - accuracy: 0.7563
# Starting iteration 2 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4524 - accuracy: 0.8235
# Starting iteration 3 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4102 - accuracy: 0.8445
# Starting iteration 4 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3708 - accuracy: 0.8445
# Starting iteration 5 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2989 - accuracy: 0.8950
# Starting iteration 6 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2808 - accuracy: 0.8908
# Starting iteration 7 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2771 - accuracy: 0.8697
# Starting iteration 8 now...
# ...

# %%
do_shapley_value_naive(0.2, 10, False, 10, 50)
# Out:
# Starting iteration 0 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5488 - accuracy: 0.7899
# Starting iteration 1 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5727 - accuracy: 0.7983
# Starting iteration 2 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5857 - accuracy: 0.7605
# Starting iteration 3 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5439 - accuracy: 0.7731
# Starting iteration 4 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5654 - accuracy: 0.8109
# Starting iteration 5 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5327 - accuracy: 0.7731
# Starting iteration 6 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5153 - accuracy: 0.7689
# Starting iteration 7 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5336 - accuracy: 0.7521
# Starting iteration 8 now...
# ...

# %%
measure_shapley_naive_exec_time(0.2, 10, True, 10, 50, 3)
# Out:
# Starting iteration 0 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5620 - accuracy: 0.7605
# Starting iteration 1 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5457 - accuracy: 0.7647
# Starting iteration 2 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4774 - accuracy: 0.8403
# Starting iteration 3 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4421 - accuracy: 0.8403
# Starting iteration 4 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3195 - accuracy: 0.8866
# Starting iteration 5 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2873 - accuracy: 0.9076
# Starting iteration 6 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2159 - accuracy: 0.9370
# Starting iteration 7 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2608 - accuracy: 0.9076
# Starting iteration 8 now...
# ...

# %%
measure_shapley_opt_exec_time(0.2, 10, True, 10, 50, 3)
# Out:
# Starting iteration 0 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5785 - accuracy: 0.7563
# Starting iteration 1 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5428 - accuracy: 0.8025
# Starting iteration 2 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4992 - accuracy: 0.7857
# Starting iteration 3 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3923 - accuracy: 0.8655
# Starting iteration 4 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4121 - accuracy: 0.8487
# Starting iteration 5 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3372 - accuracy: 0.8782
# Starting iteration 6 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3228 - accuracy: 0.8866
# Starting iteration 7 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3049 - accuracy: 0.8866
# Starting iteration 8 now...
# ...
