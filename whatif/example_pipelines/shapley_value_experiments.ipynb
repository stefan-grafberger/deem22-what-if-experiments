# %%
from product_images_shapley_naive import print_legend, do_shapley_value_naive, measure_shapley_naive_exec_time
from whatif.example_pipelines.product_images_shapley_opt import measure_shapley_opt_exec_time, do_shapley_value_opt
from whatif.example_pipelines.product_images_shapley_qualitative import do_shapley_value_qualitative
print_legend()
# Out:
# iteration: In each iteration, we execute the pipeline and clean #cleaning_batch_size rows afterwards, either using shapley values or random sampling. Param for this: $use_shapley_weighting
# already_cleaned_rows: Already cleaned rows
# total_corrupted_rows: Total corrupted rows
# false_corruption_alarm: False alarms in that iteration for #rows that were not corrupted
# correct_corruption_alarm: Correct alarms in that iteration for #rows that were corrupted
# corruption_not_detected_yet: In that and previous iterations, there were corrupted #rows not discover yet
# fraction_data_cleaned: fraction of corrupted data that was cleaned already
# model_score: Model score on current data with potential left-over corruptions

# %%
do_shapley_value_qualitative(0.5, 10, True, 10, 50)
# Out:
# Starting iteration 0 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6847 - accuracy: 0.6304
# Starting iteration 1 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6463 - accuracy: 0.8565
# Starting iteration 2 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5913 - accuracy: 0.7565
# Starting iteration 3 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5588 - accuracy: 0.8130
# Starting iteration 4 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4709 - accuracy: 0.8522
# Starting iteration 5 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3725 - accuracy: 0.8696
# Starting iteration 6 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4259 - accuracy: 0.8652
# Starting iteration 7 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3644 - accuracy: 0.9043
# Starting iteration 8 now...
# ...

# %%
do_shapley_value_qualitative(0.5, 10, False, 10, 50)
# Out:
# Starting iteration 0 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6964 - accuracy: 0.3067
# Starting iteration 1 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.7036 - accuracy: 0.5042
# Starting iteration 2 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6506 - accuracy: 0.5294
# Starting iteration 3 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6331 - accuracy: 0.7143
# Starting iteration 4 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6511 - accuracy: 0.8697
# Starting iteration 5 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6431 - accuracy: 0.9076
# Starting iteration 6 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6096 - accuracy: 0.9076
# Starting iteration 7 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6032 - accuracy: 0.8613
# Starting iteration 8 now...
# ...

# %%
measure_shapley_naive_exec_time(0.2, 10, True, 10, 50, True, 5)
# Out:
# Starting iteration 0 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5946 - accuracy: 0.7521
# Starting iteration 1 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5375 - accuracy: 0.7815
# Starting iteration 2 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4611 - accuracy: 0.8067
# Starting iteration 3 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3365 - accuracy: 0.8529
# Starting iteration 4 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3162 - accuracy: 0.8739
# Starting iteration 5 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2557 - accuracy: 0.9160
# Starting iteration 6 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2360 - accuracy: 0.9034
# Starting iteration 7 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1935 - accuracy: 0.9076
# Starting iteration 8 now...
# ...

# %%
measure_shapley_naive_exec_time(0.2, 10, True, 10, 50, False, 5)
# Out:
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
# Starting iteration 0 now...
# Starting iteration 1 now...
# ...

# %%
measure_shapley_opt_exec_time(0.2, 10, True, 10, 50, True, 5)
# Out:
# Starting iteration 0 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6162 - accuracy: 0.7143
# Starting iteration 1 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5382 - accuracy: 0.7647
# Starting iteration 2 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5074 - accuracy: 0.7773
# Starting iteration 3 now...
# ...
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4418 - accuracy: 0.8067
# Starting iteration 4 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4580 - accuracy: 0.8445
# Starting iteration 5 now...
# ...
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4200 - accuracy: 0.8655
# Starting iteration 6 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3976 - accuracy: 0.8529
# Starting iteration 7 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3738 - accuracy: 0.8697
# Starting iteration 8 now...
# ...

# %%
measure_shapley_opt_exec_time(0.2, 10, True, 10, 50, False, 5)
# Out:
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
# Starting iteration 0 now...
# Starting iteration 1 now...
# ...

# %%
do_shapley_value_opt(0.2, 10, True, 10, 50, True)
do_shapley_value_opt(0.2, 10, True, 10, 50, True)
do_shapley_value_opt(0.2, 10, True, 10, 50, True)
do_shapley_value_opt(0.2, 10, True, 10, 50, True)
do_shapley_value_opt(0.2, 10, True, 10, 50, True)
# Out:
# Starting iteration 0 now...
# ...
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5656 - accuracy: 0.7647
# Starting iteration 1 now...
# ...
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5267 - accuracy: 0.7941
# Starting iteration 2 now...
# ...
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4898 - accuracy: 0.8193
# Starting iteration 3 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4306 - accuracy: 0.8487
# Starting iteration 4 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3639 - accuracy: 0.8655
# Starting iteration 5 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3763 - accuracy: 0.8739
# Starting iteration 6 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3594 - accuracy: 0.8824
# Starting iteration 7 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3269 - accuracy: 0.8992
# Starting iteration 8 now...
# ...

# %%
do_shapley_value_opt(0.2, 10, True, 10, 50, False)
# Out:
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
#    iteration  already_cleaned_rows  total_corrupted_rows  \
# 0          0                     0                   238
# 1          1                    50                   238
# 2          2                    81                   238
# 3          3                   106                   238
# 4          4                   120                   238
# 5          5                   135                   238
# 6          6                   145                   238
# 7          7                   150                   238
# 8          8                   154                   238
# 9          9                   158                   238
#
# ...

# %%
do_shapley_value_naive(0.2, 10, True, 10, 50, True)
do_shapley_value_naive(0.2, 10, True, 10, 50, True)
do_shapley_value_naive(0.2, 10, True, 10, 50, True)
do_shapley_value_naive(0.2, 10, True, 10, 50, True)
do_shapley_value_naive(0.2, 10, True, 10, 50, True)
# Out:
# Starting iteration 0 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5828 - accuracy: 0.7521
# Starting iteration 1 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5420 - accuracy: 0.7731
# Starting iteration 2 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4738 - accuracy: 0.8235
# Starting iteration 3 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3361 - accuracy: 0.9118
# Starting iteration 4 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3147 - accuracy: 0.9076
# Starting iteration 5 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3075 - accuracy: 0.8824
# Starting iteration 6 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2554 - accuracy: 0.8950
# Starting iteration 7 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1879 - accuracy: 0.9076
# Starting iteration 8 now...
# ...

# %%
# Out:
# Starting iteration 0 now...
# ...
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5549 - accuracy: 0.7815
# Starting iteration 1 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5426 - accuracy: 0.7773
# Starting iteration 2 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4604 - accuracy: 0.7899
# Starting iteration 3 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3544 - accuracy: 0.9034
# Starting iteration 4 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2959 - accuracy: 0.8782
# Starting iteration 5 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2579 - accuracy: 0.9370
# Starting iteration 6 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2495 - accuracy: 0.9286
# Starting iteration 7 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1968 - accuracy: 0.9160
# Starting iteration 8 now...
# ...
