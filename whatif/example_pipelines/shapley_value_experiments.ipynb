# %%
from product_images_shapley_naive import print_legend, do_shapley_value_naive
print_legend()
do_shapley_value_naive(0.2, 10, True, 10, 50)
# Out:
# iteration: In each iteration, we execute the pipeline and clean #cleaning_batch_size rows afterwards, either using shapley values or random sampling. Param for this: $use_shapley_weighting
# already_cleaned_rows: Already cleaned rows
# total_corrupted_rows: Total corrupted rows
# false_corruption_alarm: False alarms in that iteration for #rows that were not corrupted
# correct_corruption_alarm: Correct alarms in that iteration for #rows that were corrupted
# corruption_not_detected_yet: In that and previous iterations, there were corrupted #rows not discover yet
# fraction_data_cleaned: fraction of corrupted data that was cleaned already
# model_score: Model score on current data with potential left-over corruptions
# Starting iteration 0 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.6045 - accuracy: 0.6842
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5779 - accuracy: 0.7605
# Starting iteration 1 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.5581 - accuracy: 0.7221
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5200 - accuracy: 0.8025
# Starting iteration 2 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.4717 - accuracy: 0.7863
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4602 - accuracy: 0.7983
# Starting iteration 3 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.4279 - accuracy: 0.8221
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4401 - accuracy: 0.8319
# Starting iteration 4 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3919 - accuracy: 0.8484
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2996 - accuracy: 0.9160
# Starting iteration 5 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3737 - accuracy: 0.8495
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2923 - accuracy: 0.8824
# Starting iteration 6 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3130 - accuracy: 0.8758
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2671 - accuracy: 0.8697
# Starting iteration 7 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2973 - accuracy: 0.8905
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2309 - accuracy: 0.9160
# Starting iteration 8 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2817 - accuracy: 0.8884
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2595 - accuracy: 0.9034
# Starting iteration 9 now...
# 30/30 [==============================] - 1s 20ms/step - loss: 0.2824 - accuracy: 0.8874
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2475 - accuracy: 0.9034
# Done!
# 2022-02-16 13:03:47.562289: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-16 13:03:47.638711: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
#    iteration  already_cleaned_rows  total_corrupted_rows  \
# 0          0                     0                   238
# 1          1                    49                   238
# 2          2                    98                   238
# 3          3                   137                   238
# 4          4                   170                   238
# 5          5                   193                   238
# 6          6                   205                   238
# 7          7                   217                   238
# 8          8                   224                   238
# 9          9                   228                   238
#
#    false_corruption_alarm  correct_corruption_alarm  \
# 0                       1                        49
# 1                       1                        49
# 2                      11                        39
# 3                      17                        33
# 4                      27                        23
# 5                      38                        12
# 6                      38                        12
# 7                      43                         7
# 8                      46                         4
# 9                      48                         2
#
#    corruption_not_detected_yet  fraction_data_cleaned  model_score
# 0                          189               0.205882     0.760504
# 1                          140               0.411765     0.802521
# 2                          101               0.575630     0.798319
# 3                           68               0.714286     0.831933
# 4                           45               0.810924     0.915966
# 5                           33               0.861345     0.882353
# 6                           21               0.911765     0.869748
# 7                           14               0.941176     0.915966
# 8                           10               0.957983     0.903361
# 9                            8               0.966387     0.903361

# %%
do_shapley_value_naive(0.2, 10, False, 10, 50)
# Out:
# Starting iteration 0 now...
# 30/30 [==============================] - 1s 22ms/step - loss: 0.5771 - accuracy: 0.7389
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6131 - accuracy: 0.6891
# Starting iteration 1 now...
# 30/30 [==============================] - 1s 22ms/step - loss: 0.5703 - accuracy: 0.7337
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5946 - accuracy: 0.7269
# Starting iteration 2 now...
# 30/30 [==============================] - 1s 23ms/step - loss: 0.5845 - accuracy: 0.7400
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5354 - accuracy: 0.7941
# Starting iteration 3 now...
# 30/30 [==============================] - 1s 22ms/step - loss: 0.5491 - accuracy: 0.7463
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5930 - accuracy: 0.7185
# Starting iteration 4 now...
# 30/30 [==============================] - 1s 21ms/step - loss: 0.5522 - accuracy: 0.7505
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5877 - accuracy: 0.7059
# Starting iteration 5 now...
# 30/30 [==============================] - 1s 22ms/step - loss: 0.5354 - accuracy: 0.7663
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6106 - accuracy: 0.7059
# Starting iteration 6 now...
# 30/30 [==============================] - 1s 22ms/step - loss: 0.5294 - accuracy: 0.7842
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5663 - accuracy: 0.7647
# Starting iteration 7 now...
# 30/30 [==============================] - 1s 19ms/step - loss: 0.5535 - accuracy: 0.7621
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5457 - accuracy: 0.7647
# Starting iteration 8 now...
# 30/30 [==============================] - 1s 22ms/step - loss: 0.5313 - accuracy: 0.7653
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5415 - accuracy: 0.7647
# Starting iteration 9 now...
# 30/30 [==============================] - 1s 18ms/step - loss: 0.5097 - accuracy: 0.7789
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5439 - accuracy: 0.7479
# Done!
#    iteration  already_cleaned_rows  total_corrupted_rows  \
# 0          0                     0                   238
# 1          1                     9                   238
# 2          2                    19                   238
# 3          3                    28                   238
# 4          4                    38                   238
# 5          5                    45                   238
# 6          6                    51                   238
# 7          7                    55                   238
# 8          8                    63                   238
# 9          9                    68                   238
#
#    false_corruption_alarm  correct_corruption_alarm  \
# 0                      41                         9
# 1                      40                        10
# 2                      41                         9
# 3                      40                        10
# 4                      43                         7
# 5                      44                         6
# 6                      46                         4
# 7                      42                         8
# 8                      45                         5
# 9                      44                         6
#
#    corruption_not_detected_yet  fraction_data_cleaned  model_score
# 0                          229               0.037815     0.689076
# 1                          219               0.079832     0.726891
# 2                          210               0.117647     0.794118
# 3                          200               0.159664     0.718487
# 4                          193               0.189076     0.705882
# 5                          187               0.214286     0.705882
# 6                          183               0.231092     0.764706
# 7                          175               0.264706     0.764706
# 8                          170               0.285714     0.764706
# 9                          164               0.310924     0.747899
