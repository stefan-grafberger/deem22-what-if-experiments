# %%
from whatif.example_pipelines.helpful_reviews_data_corruptions_naive import do_review_corruption_naive, \
    measure_review_corruption_naive_exec_time
from whatif.example_pipelines.helpful_reviews_data_corruptions_opt import do_review_corruption_opt, \
    measure_review_corruption_opt_exec_time
from whatif.utils.utils import get_project_root

def save_to_csv(df, filename):
    df.to_csv(f'{str(get_project_root())}/whatif/example_pipelines/datasets/sneakers/{filename}.csv',
              index=False)

# %%
corruption_qualitative_review_corruption_naive = do_review_corruption_naive(debug=True,
                                                                          corruption_percentages=[0.2, 0.5, 0.9],
                                                                          corrupt_features=["star_rating", "verified_purchase", "review_headline"])
save_to_csv(corruption_qualitative_review_corruption_naive, "corruption_qualitative_review_corruption_naive")
corruption_qualitative_review_corruption_naive
# Out:
# No corruptions
# AUC Score on the test set: 0.6013602667383573
# F1 Score on the test set: 0.5831241333597452
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6028164569238206
# F1 Score on the test set: 0.5901077631770447
# Corruptions in Train and test
# AUC Score on the test set: 0.6031228024753794
# F1 Score on the test set: 0.5997706189488651
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6053172274137595
# F1 Score on the test set: 0.5993630717108978
# Corruptions in Train and test
# AUC Score on the test set: 0.601851189855569
# F1 Score on the test set: 0.566234598974064
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6013793798232985
# F1 Score on the test set: 0.5766220162346894
# Corruptions in Train and test
# AUC Score on the test set: 0.6005013504165355
# F1 Score on the test set: 0.5781250171029997
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6050280257235303
# F1 Score on the test set: 0.605403500168572
# Corruptions in Train and test
# AUC Score on the test set: 0.6055237151637056
# F1 Score on the test set: 0.6039867750927708
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6068038588058081
# F1 Score on the test set: 0.6058185454719964
# Corruptions in Train and test
# AUC Score on the test set: 0.6045240713937132
# F1 Score on the test set: 0.5901500020016988
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6072175762032619
# F1 Score on the test set: 0.6100857647244116
# Corruptions in Train and test
# AUC Score on the test set: 0.6131776478897601
# F1 Score on the test set: 0.6221622689418825
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6042352772777071
# F1 Score on the test set: 0.6017337382941027
# Corruptions in Train and test
# AUC Score on the test set: 0.6094667563693802
# F1 Score on the test set: 0.6154918375427632
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.605432665414179
# F1 Score on the test set: 0.6049846705376731
# Corruptions in Train and test
# AUC Score on the test set: 0.6038019565685929
# F1 Score on the test set: 0.5920361761143884
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.603802203614469
# F1 Score on the test set: 0.584463686989614
# Corruptions in Train and test
# AUC Score on the test set: 0.6054767935914834
# F1 Score on the test set: 0.6026955596142812
#     test_corruption  train_corruption  corruption_fraction            feature  \
# 0             False             False                  NaN               None
# 1             False              True                  0.2        star_rating
# 2              True              True                  0.2        star_rating
# 3             False              True                  0.5        star_rating
# 4              True              True                  0.5        star_rating
# 5             False              True                  0.9        star_rating
# 6              True              True                  0.9        star_rating
# 7             False              True                  0.2  verified_purchase
# 8              True              True                  0.2  verified_purchase
# 9             False              True                  0.5  verified_purchase
# 10             True              True                  0.5  verified_purchase
# 11            False              True                  0.9  verified_purchase
# 12             True              True                  0.9  verified_purchase
# 13            False              True                  0.2    review_headline
# 14             True              True                  0.2    review_headline
# 15            False              True                  0.5    review_headline
# 16             True              True                  0.5    review_headline
# 17            False              True                  0.9    review_headline
# 18             True              True                  0.9    review_headline
#
#      roc_auc        f1
# 0   0.601360  0.583124
# 1   0.602816  0.590108
# 2   0.603123  0.599771
# 3   0.605317  0.599363
# 4   0.601851  0.566235
# 5   0.601379  0.576622
# 6   0.600501  0.578125
# 7   0.605028  0.605404
# 8   0.605524  0.603987
# 9   0.606804  0.605819
# 10  0.604524  0.590150
# 11  0.607218  0.610086
# 12  0.613178  0.622162
# 13  0.604235  0.601734
# 14  0.609467  0.615492
# 15  0.605433  0.604985
# 16  0.603802  0.592036
# 17  0.603802  0.584464
# 18  0.605477  0.602696

# %%
review_corruption_naive_exec_times = measure_review_corruption_naive_exec_time(debug=True,
                                                                               corruption_percentages=[0.2, 0.5, 0.9],
                                                                               corrupt_features=["star_rating", "verified_purchase", "review_headline"],
                                                                               repeats=10)
save_to_csv(review_corruption_naive_exec_times, "review_corruption_naive_exec_times")
review_corruption_naive_exec_times
# Out:
# No corruptions
# AUC Score on the test set: 0.5984508006428955
# F1 Score on the test set: 0.5614683097196187
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6024682089827793
# F1 Score on the test set: 0.581001657645398
# Corruptions in Train and test
# AUC Score on the test set: 0.6070430759940066
# F1 Score on the test set: 0.6097993074694368
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.604437509916962
# F1 Score on the test set: 0.5943131232905232
# Corruptions in Train and test
# AUC Score on the test set: 0.6021026329930146
# F1 Score on the test set: 0.5948255198025129
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6055088702147526
# F1 Score on the test set: 0.5983168334763083
# Corruptions in Train and test
# AUC Score on the test set: 0.6035558436293025
# F1 Score on the test set: 0.5951431846111197
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6043126375056789
# F1 Score on the test set: 0.5836128059299631
# Corruptions in Train and test
# AUC Score on the test set: 0.604017265595002
# F1 Score on the test set: 0.5823261045442212
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6035091338759894
# F1 Score on the test set: 0.5960198880858592
# Corruptions in Train and test
# AUC Score on the test set: 0.6028074587936174
# F1 Score on the test set: 0.5992111213069928
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6031146543576498
# F1 Score on the test set: 0.5943118265353342
# Corruptions in Train and test
# AUC Score on the test set: 0.5971329584746244
# F1 Score on the test set: 0.5470568289185079
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6030246545073141
# F1 Score on the test set: 0.587129546079956
# Corruptions in Train and test
# AUC Score on the test set: 0.6091922646654393
# F1 Score on the test set: 0.6147822301771196
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6019570822156827
# F1 Score on the test set: 0.5872912834938152
# Corruptions in Train and test
# AUC Score on the test set: 0.601855927786801
# F1 Score on the test set: 0.5769668162059849
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.601333960236432
# F1 Score on the test set: 0.5938710451730723
# Corruptions in Train and test
# AUC Score on the test set: 0.6059550610123949
# F1 Score on the test set: 0.6076649663569751
# Done!
# No corruptions
# AUC Score on the test set: 0.6045063308342205
# F1 Score on the test set: 0.6059394808224761
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6033605925152832
# F1 Score on the test set: 0.6057191201653747
# Corruptions in Train and test
# AUC Score on the test set: 0.6044272708141813
# F1 Score on the test set: 0.6028658754006255
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6031770786917388
# F1 Score on the test set: 0.5934314925196384
# Corruptions in Train and test
# AUC Score on the test set: 0.602535910612886
# F1 Score on the test set: 0.5960891797379311
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6043751643871647
# F1 Score on the test set: 0.6011590623942007
# Corruptions in Train and test
# AUC Score on the test set: 0.6049749614552332
# F1 Score on the test set: 0.6063759741344577
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6032744780502082
# F1 Score on the test set: 0.59919859596564
# Corruptions in Train and test
# AUC Score on the test set: 0.6046824233481431
# F1 Score on the test set: 0.5995580312742669
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6006142992507026
# F1 Score on the test set: 0.5720452727349279
# Corruptions in Train and test
# AUC Score on the test set: 0.6024958180764468
# F1 Score on the test set: 0.5990751121076233
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.60813434470672
# F1 Score on the test set: 0.605745871016475
# Corruptions in Train and test
# AUC Score on the test set: 0.6026501999014184
# F1 Score on the test set: 0.5989316021204636
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6036966650635804
# F1 Score on the test set: 0.5873138053095086
# Corruptions in Train and test
# AUC Score on the test set: 0.6043750608812356
# F1 Score on the test set: 0.5989991086157731
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6027080707484611
# F1 Score on the test set: 0.5930427361234037
# Corruptions in Train and test
# AUC Score on the test set: 0.6046356531099359
# F1 Score on the test set: 0.6039946571806247
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6168009773271591
# F1 Score on the test set: 0.6304400209202708
# Corruptions in Train and test
# AUC Score on the test set: 0.6074067040713566
# F1 Score on the test set: 0.6113448104717598
# Done!
# No corruptions
# AUC Score on the test set: 0.6032264531092199
# F1 Score on the test set: 0.579951524924351
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.605625403018768
# F1 Score on the test set: 0.6025440924387481
# Corruptions in Train and test
# AUC Score on the test set: 0.60651960671837
# F1 Score on the test set: 0.6099090167476665
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.606801394236706
# F1 Score on the test set: 0.6076810022259103
# Corruptions in Train and test
# AUC Score on the test set: 0.60343112079475
# F1 Score on the test set: 0.5879519423397791
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6057345307782502
# F1 Score on the test set: 0.6051248424387077
# Corruptions in Train and test
# AUC Score on the test set: 0.6036795737920632
# F1 Score on the test set: 0.5958597515014306
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.608033052291941
# F1 Score on the test set: 0.6110972153995752
# Corruptions in Train and test
# AUC Score on the test set: 0.6045361152160951
# F1 Score on the test set: 0.598842716831258
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6030055465132815
# F1 Score on the test set: 0.5915501230631925
# Corruptions in Train and test
# AUC Score on the test set: 0.6115310177322887
# F1 Score on the test set: 0.6199235684584831
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6003797167469528
# F1 Score on the test set: 0.5707650918332726
# Corruptions in Train and test
# AUC Score on the test set: 0.6056117621172592
# F1 Score on the test set: 0.6008007988801136
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6098412859229033
# F1 Score on the test set: 0.6155229363351151
# Corruptions in Train and test
# AUC Score on the test set: 0.6048231318191175
# F1 Score on the test set: 0.6074636041079922
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.604877195653877
# F1 Score on the test set: 0.6028589780149272
# Corruptions in Train and test
# AUC Score on the test set: 0.6037186876524052
# F1 Score on the test set: 0.592930036306545
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6006170981336545
# F1 Score on the test set: 0.5713036708400788
# Corruptions in Train and test
# AUC Score on the test set: 0.6018981198829036
# F1 Score on the test set: 0.5877389236239922
# Done!
# No corruptions
# AUC Score on the test set: 0.6027218603554481
# F1 Score on the test set: 0.5909990338561139
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.606561290660848
# F1 Score on the test set: 0.6065420839170336
# Corruptions in Train and test
# AUC Score on the test set: 0.6017323604960904
# F1 Score on the test set: 0.5766960227518947
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6048421366775553
# F1 Score on the test set: 0.5994014376777957
# Corruptions in Train and test
# AUC Score on the test set: 0.6039436249375509
# F1 Score on the test set: 0.5923121557951808
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6000733948490714
# F1 Score on the test set: 0.5758512209494588
# Corruptions in Train and test
# AUC Score on the test set: 0.6069880838785896
# F1 Score on the test set: 0.6093778215076286
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6049899465450443
# F1 Score on the test set: 0.6009870959879761
# Corruptions in Train and test
# AUC Score on the test set: 0.6064284811832015
# F1 Score on the test set: 0.6066857001613588
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.60298822205613
# F1 Score on the test set: 0.58402238337986
# Corruptions in Train and test
# AUC Score on the test set: 0.6026563247380092
# F1 Score on the test set: 0.5976548565370177
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6001781446816443
# F1 Score on the test set: 0.5753887482035676
# Corruptions in Train and test
# AUC Score on the test set: 0.6025297376871669
# F1 Score on the test set: 0.5932052139787202
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6060030947239838
# F1 Score on the test set: 0.6080843999892946
# Corruptions in Train and test
# AUC Score on the test set: 0.6013620005057032
# F1 Score on the test set: 0.5699393433047001
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.602687435879411
# F1 Score on the test set: 0.5808092693801811
# Corruptions in Train and test
# AUC Score on the test set: 0.604833702592658
# F1 Score on the test set: 0.600706753233703
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6027080707484611
# F1 Score on the test set: 0.5930427361234037
# Corruptions in Train and test
# AUC Score on the test set: 0.6028087360435084
# F1 Score on the test set: 0.5776531672051396
# Done!
# No corruptions
# AUC Score on the test set: 0.6030213887356745
# F1 Score on the test set: 0.5960577173412374
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.60627249666941
# F1 Score on the test set: 0.5962929132208405
# Corruptions in Train and test
# AUC Score on the test set: 0.5977729537532568
# F1 Score on the test set: 0.5729145647696507
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6042360316505522
# F1 Score on the test set: 0.5872181650750655
# Corruptions in Train and test
# AUC Score on the test set: 0.6031146543576498
# F1 Score on the test set: 0.5943118265353342
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.602942240843247
# F1 Score on the test set: 0.5813533955551424
# Corruptions in Train and test
# AUC Score on the test set: 0.6130506868782568
# F1 Score on the test set: 0.6247721438612162
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6043697361902403
# F1 Score on the test set: 0.5874923611641586
# Corruptions in Train and test
# AUC Score on the test set: 0.5995991784164887
# F1 Score on the test set: 0.5819329040059138
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6036452998835923
# F1 Score on the test set: 0.585388390086186
# Corruptions in Train and test
# AUC Score on the test set: 0.6034379434121186
# F1 Score on the test set: 0.5855752643569181
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.5993056712349512
# F1 Score on the test set: 0.5727674268499927
# Corruptions in Train and test
# AUC Score on the test set: 0.6031293102879355
# F1 Score on the test set: 0.6001945472113532
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6042959873820408
# F1 Score on the test set: 0.5965314831037137
# Corruptions in Train and test
# AUC Score on the test set: 0.602476313522825
# F1 Score on the test set: 0.5783221318240774
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6041950308710686
# F1 Score on the test set: 0.6039885327382611
# Corruptions in Train and test
# AUC Score on the test set: 0.6026514965752865
# F1 Score on the test set: 0.5980816622208983
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.606939748456374
# F1 Score on the test set: 0.6108991959837741
# Corruptions in Train and test
# AUC Score on the test set: 0.6048608097668071
# F1 Score on the test set: 0.6051201666980827
# Done!
# No corruptions
# AUC Score on the test set: 0.6054913958134465
# F1 Score on the test set: 0.5920794059393165
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5994239711291554
# F1 Score on the test set: 0.5621084674584037
# Corruptions in Train and test
# AUC Score on the test set: 0.601640126045992
# F1 Score on the test set: 0.5899577806159094
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6038990145824448
# F1 Score on the test set: 0.5871296685653121
# Corruptions in Train and test
# AUC Score on the test set: 0.6029243137462316
# F1 Score on the test set: 0.5924371146120978
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6053163718317516
# F1 Score on the test set: 0.6069447372489494
# Corruptions in Train and test
# AUC Score on the test set: 0.6064219208559245
# F1 Score on the test set: 0.6080990328060202
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6017014730321413
# F1 Score on the test set: 0.5832144049992859
# Corruptions in Train and test
# AUC Score on the test set: 0.6048510313216195
# F1 Score on the test set: 0.602001571143334
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6046786607543331
# F1 Score on the test set: 0.5999928828227603
# Corruptions in Train and test
# AUC Score on the test set: 0.6021571483520296
# F1 Score on the test set: 0.5898983377689109
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6041840171463564
# F1 Score on the test set: 0.583339826006802
# Corruptions in Train and test
# AUC Score on the test set: 0.6016112305861552
# F1 Score on the test set: 0.5798338510483729
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.60055013185523
# F1 Score on the test set: 0.576199482010099
# Corruptions in Train and test
# AUC Score on the test set: 0.602033199899797
# F1 Score on the test set: 0.5813820630817683
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6009768114820532
# F1 Score on the test set: 0.5784775229769897
# Corruptions in Train and test
# AUC Score on the test set: 0.6033933246453738
# F1 Score on the test set: 0.5928223864006904
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6035192853961291
# F1 Score on the test set: 0.5914845880430484
# Corruptions in Train and test
# AUC Score on the test set: 0.6020184769272361
# F1 Score on the test set: 0.586842349173641
# Done!
# No corruptions
# AUC Score on the test set: 0.6038990236382322
# F1 Score on the test set: 0.5994590712094405
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.604812117808362
# F1 Score on the test set: 0.5960367322108869
# Corruptions in Train and test
# AUC Score on the test set: 0.6065215883100237
# F1 Score on the test set: 0.6089410353752475
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5997831848343107
# F1 Score on the test set: 0.5603823207815662
# Corruptions in Train and test
# AUC Score on the test set: 0.6039577714649378
# F1 Score on the test set: 0.5968537884057276
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6059805895410666
# F1 Score on the test set: 0.5895886924863408
# Corruptions in Train and test
# AUC Score on the test set: 0.6043946958802587
# F1 Score on the test set: 0.5981268528130652
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6046786607543331
# F1 Score on the test set: 0.5999928828227603
# Corruptions in Train and test
# AUC Score on the test set: 0.6042114188807236
# F1 Score on the test set: 0.5995868860374403
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6034605791418244
# F1 Score on the test set: 0.5843802305384495
# Corruptions in Train and test
# AUC Score on the test set: 0.6044039157696119
# F1 Score on the test set: 0.5947592067988668
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6045072622386392
# F1 Score on the test set: 0.5889604571838143
# Corruptions in Train and test
# AUC Score on the test set: 0.597619001971678
# F1 Score on the test set: 0.5704649178298244
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6039094777244406
# F1 Score on the test set: 0.585935529667408
# Corruptions in Train and test
# AUC Score on the test set: 0.606986739449022
# F1 Score on the test set: 0.6103520471643018
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6038767755746144
# F1 Score on the test set: 0.5952574866133404
# Corruptions in Train and test
# AUC Score on the test set: 0.6062409682475235
# F1 Score on the test set: 0.6027990006063557
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6037659583729766
# F1 Score on the test set: 0.5880450016318851
# Corruptions in Train and test
# AUC Score on the test set: 0.6095388612253734
# F1 Score on the test set: 0.6194942458702581
# Done!
# No corruptions
# AUC Score on the test set: 0.604617338317915
# F1 Score on the test set: 0.5941426318380699
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6041474720872515
# F1 Score on the test set: 0.5962535510274204
# Corruptions in Train and test
# AUC Score on the test set: 0.6171070480422949
# F1 Score on the test set: 0.62978842722308
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6040755091979171
# F1 Score on the test set: 0.6014528239031735
# Corruptions in Train and test
# AUC Score on the test set: 0.6021821825425396
# F1 Score on the test set: 0.5976703602046693
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6127991402724609
# F1 Score on the test set: 0.6208906280670289
# Corruptions in Train and test
# AUC Score on the test set: 0.6063146260741294
# F1 Score on the test set: 0.6049694381818707
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6025069639306202
# F1 Score on the test set: 0.5817367718468136
# Corruptions in Train and test
# AUC Score on the test set: 0.5995379574738128
# F1 Score on the test set: 0.5703620853335682
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6102185685936312
# F1 Score on the test set: 0.615547021680647
# Corruptions in Train and test
# AUC Score on the test set: 0.6066950832582234
# F1 Score on the test set: 0.6092269434060287
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6031725832844099
# F1 Score on the test set: 0.5885844933947915
# Corruptions in Train and test
# AUC Score on the test set: 0.6056764472623809
# F1 Score on the test set: 0.5981513016688896
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.602066631035097
# F1 Score on the test set: 0.5956858932803999
# Corruptions in Train and test
# AUC Score on the test set: 0.6017050800102635
# F1 Score on the test set: 0.5793715261095943
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.602476313522825
# F1 Score on the test set: 0.5783221318240774
# Corruptions in Train and test
# AUC Score on the test set: 0.6076927526787275
# F1 Score on the test set: 0.6140741162024925
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6058706079699802
# F1 Score on the test set: 0.586896456927252
# Corruptions in Train and test
# AUC Score on the test set: 0.6088160622982492
# F1 Score on the test set: 0.6152863291276978
# Done!
# No corruptions
# AUC Score on the test set: 0.5993145507405517
# F1 Score on the test set: 0.5643568746836799
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.604023933814241
# F1 Score on the test set: 0.5955349290337749
# Corruptions in Train and test
# AUC Score on the test set: 0.6039436249375509
# F1 Score on the test set: 0.5923121557951808
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6042706678768626
# F1 Score on the test set: 0.5924151470680072
# Corruptions in Train and test
# AUC Score on the test set: 0.6030596103433397
# F1 Score on the test set: 0.589486216283994
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6028173789451985
# F1 Score on the test set: 0.5975053413286324
# Corruptions in Train and test
# AUC Score on the test set: 0.6036315126744282
# F1 Score on the test set: 0.5865817482748963
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6065835131635735
# F1 Score on the test set: 0.6103247181107931
# Corruptions in Train and test
# AUC Score on the test set: 0.6055995281106756
# F1 Score on the test set: 0.5911623411238063
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6053181903510418
# F1 Score on the test set: 0.6149129314234585
# Corruptions in Train and test
# AUC Score on the test set: 0.6012284768143729
# F1 Score on the test set: 0.5828517721182997
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6109070315245576
# F1 Score on the test set: 0.61849979485376
# Corruptions in Train and test
# AUC Score on the test set: 0.6033648019621737
# F1 Score on the test set: 0.5860342632249104
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6008342548540568
# F1 Score on the test set: 0.5820353152193891
# Corruptions in Train and test
# AUC Score on the test set: 0.6031429476191608
# F1 Score on the test set: 0.5972016310086979
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6058309233061073
# F1 Score on the test set: 0.6077992157458993
# Corruptions in Train and test
# AUC Score on the test set: 0.6094255498000727
# F1 Score on the test set: 0.6124019932120857
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6036131427569833
# F1 Score on the test set: 0.5942616004565815
# Corruptions in Train and test
# AUC Score on the test set: 0.600395493145132
# F1 Score on the test set: 0.5847311869392369
# Done!
# No corruptions
# AUC Score on the test set: 0.6036399785061795
# F1 Score on the test set: 0.5967344690613938
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.60592552134239
# F1 Score on the test set: 0.587639580046122
# Corruptions in Train and test
# AUC Score on the test set: 0.6025156796572819
# F1 Score on the test set: 0.5836633926469956
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6016230508997773
# F1 Score on the test set: 0.5871910314875871
# Corruptions in Train and test
# AUC Score on the test set: 0.6011998836525768
# F1 Score on the test set: 0.5782866801110638
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6008510659464191
# F1 Score on the test set: 0.5663456738143213
# Corruptions in Train and test
# AUC Score on the test set: 0.6040330637770732
# F1 Score on the test set: 0.5874037929393152
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6032054984212498
# F1 Score on the test set: 0.6022961189914442
# Corruptions in Train and test
# AUC Score on the test set: 0.6013979171957227
# F1 Score on the test set: 0.5979604363931911
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6022964435830963
# F1 Score on the test set: 0.5750828036434371
# Corruptions in Train and test
# AUC Score on the test set: 0.6035058851664691
# F1 Score on the test set: 0.588680647953736
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6067414557500976
# F1 Score on the test set: 0.6045170261392401
# Corruptions in Train and test
# AUC Score on the test set: 0.6056664117782714
# F1 Score on the test set: 0.6038395731309398
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6028217220968359
# F1 Score on the test set: 0.5937582554023353
# Corruptions in Train and test
# AUC Score on the test set: 0.6003320319265274
# F1 Score on the test set: 0.5617210320600151
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6051031497315884
# F1 Score on the test set: 0.6062424881701813
# Corruptions in Train and test
# AUC Score on the test set: 0.6043189723235816
# F1 Score on the test set: 0.5960902180974095
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6057313949072817
# F1 Score on the test set: 0.611296378637419
# Corruptions in Train and test
# AUC Score on the test set: 0.6021190577593794
# F1 Score on the test set: 0.588733959353984
# Done!
#     runtimes
# 0  75.858431
# 1  77.817165
# 2  75.681072
# 3  77.615748
# 4  76.266176
# 5  75.885010
# 6  75.941401
# 7  76.164451
# 8  76.921979
# 9  75.918570

# %%
# Other params hard-coded currently
# corruption_percentages=[0.2, 0.5, 0.9], corrupt_features=["star_rating", "verified_purchase", "review_headline"]
corruption_qualitative_review_corruption_opt = do_review_corruption_opt(debug=True)
save_to_csv(corruption_qualitative_review_corruption_opt, "corruption_qualitative_review_corruption_opt")
corruption_qualitative_review_corruption_opt
# Out:
# No corruptions
# AUC Score on the test set: 0.6062617472013445
# F1 Score on the test set: 0.6064017723234074
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6009507051651104
# F1 Score on the test set: 0.6102777162900781
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5699018065918198
# F1 Score on the test set: 0.5744303661653108
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5778550470445529
# F1 Score on the test set: 0.5134229318448145
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6062617472013445
# F1 Score on the test set: 0.6064017723234074
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6062617472013445
# F1 Score on the test set: 0.6064017723234074
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6062617472013445
# F1 Score on the test set: 0.6064017723234074
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6048004152023833
# F1 Score on the test set: 0.6042772093078007
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6017293817883297
# F1 Score on the test set: 0.5993532165714155
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6020506828225547
# F1 Score on the test set: 0.5999132053292546
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5829615113845474
# F1 Score on the test set: 0.5685499378345344
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5526375567178334
# F1 Score on the test set: 0.5555755639628135
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.534749252357948
# F1 Score on the test set: 0.512901594266908
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6021104031153219
# F1 Score on the test set: 0.5903413531225252
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.5995669761836901
# F1 Score on the test set: 0.5681408441122194
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6083317628498464
# F1 Score on the test set: 0.6102501982142507
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6000257398289448
# F1 Score on the test set: 0.5777713925224591
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6000392831358559
# F1 Score on the test set: 0.5743849936597284
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.5998040416411512
# F1 Score on the test set: 0.5779577785494088
#     test_corruption  train_corruption  corruption_fraction            feature  \
# 0             False             False                  NaN               None
# 1              True             False                  0.2        star_rating
# 2              True             False                  0.5        star_rating
# 3              True             False                  0.9        star_rating
# 4              True             False                  0.2  verified_purchase
# 5              True             False                  0.5  verified_purchase
# 6              True             False                  0.9  verified_purchase
# 7              True             False                  0.2    review_headline
# 8              True             False                  0.5    review_headline
# 9              True             False                  0.9    review_headline
# 10             True              True                  0.2        star_rating
# 11             True              True                  0.5        star_rating
# 12             True              True                  0.9        star_rating
# 13             True              True                  0.2  verified_purchase
# 14             True              True                  0.5  verified_purchase
# 15             True              True                  0.9  verified_purchase
# 16             True              True                  0.2    review_headline
# 17             True              True                  0.5    review_headline
# 18             True              True                  0.9    review_headline
#
#      roc_auc        f1
# 0   0.606262  0.606402
# 1   0.600951  0.610278
# 2   0.569902  0.574430
# 3   0.577855  0.513423
# 4   0.606262  0.606402
# 5   0.606262  0.606402
# 6   0.606262  0.606402
# 7   0.604800  0.604277
# 8   0.601729  0.599353
# 9   0.602051  0.599913
# 10  0.582962  0.568550
# 11  0.552638  0.555576
# 12  0.534749  0.512902
# 13  0.602110  0.590341
# 14  0.599567  0.568141
# 15  0.608332  0.610250
# 16  0.600026  0.577771
# 17  0.600039  0.574385
# 18  0.599804  0.577958

# %%
# Other params hard-coded currently
# corruption_percentages=[0.2, 0.5, 0.9], corrupt_features=["star_rating", "verified_purchase", "review_headline"]
review_corruption_opt_exec_times = measure_review_corruption_opt_exec_time(debug=True, repeats=30)
save_to_csv(review_corruption_opt_exec_times, "review_corruption_opt_exec_times")
review_corruption_opt_exec_times
# Out:
# No corruptions
# AUC Score on the test set: 0.6053090487929182
# F1 Score on the test set: 0.6019818024771257
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5884298942337216
# F1 Score on the test set: 0.5934420777336014
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5787180221458572
# F1 Score on the test set: 0.5849971084080645
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5544065337835623
# F1 Score on the test set: 0.5041326775602286
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6053090487929182
# F1 Score on the test set: 0.6019818024771257
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6053090487929182
# F1 Score on the test set: 0.6019818024771257
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6053090487929182
# F1 Score on the test set: 0.6019818024771257
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6038990236382322
# F1 Score on the test set: 0.5994590712094405
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6045220241379198
# F1 Score on the test set: 0.6001465198989063
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6012094548611298
# F1 Score on the test set: 0.5931649049627911
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5968957923884002
# F1 Score on the test set: 0.6028435170051274
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5962074775755581
# F1 Score on the test set: 0.5988416378760413
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.6025243550003496
# F1 Score on the test set: 0.6065312471554782
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.5981513598934547
# F1 Score on the test set: 0.5624269331706332
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6022979955948294
# F1 Score on the test set: 0.5901733276034953
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.604617338317915
# F1 Score on the test set: 0.5941426318380699
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6053172274137595
# F1 Score on the test set: 0.5993630717108978
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6042959873820408
# F1 Score on the test set: 0.5965314831037137
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6018813871564055
# F1 Score on the test set: 0.5909481511252044
# Done!
# No corruptions
# AUC Score on the test set: 0.6092731045682837
# F1 Score on the test set: 0.6174567017793384
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5967065002952967
# F1 Score on the test set: 0.6075000124341199
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5817096906885516
# F1 Score on the test set: 0.5837977571195555
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5631492745042254
# F1 Score on the test set: 0.509836397741065
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6092731045682837
# F1 Score on the test set: 0.6174567017793384
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6092731045682837
# F1 Score on the test set: 0.6174567017793384
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6092731045682837
# F1 Score on the test set: 0.6174567017793384
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6077183780415906
# F1 Score on the test set: 0.6151168362081674
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6035528703984532
# F1 Score on the test set: 0.6092514065027406
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6046775258639665
# F1 Score on the test set: 0.6109807958558464
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.6014535896380278
# F1 Score on the test set: 0.5901226572465901
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5607777241734648
# F1 Score on the test set: 0.5642808030129317
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5190079812699204
# F1 Score on the test set: 0.511262950549154
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.604679648378323
# F1 Score on the test set: 0.6008590689853855
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6003458389535432
# F1 Score on the test set: 0.5863344188736517
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.593725985369774
# F1 Score on the test set: 0.5346706424505286
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6025938709508092
# F1 Score on the test set: 0.5947910031132431
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6006034686682944
# F1 Score on the test set: 0.5857219595440757
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6056437421015957
# F1 Score on the test set: 0.5990391007121173
# Done!
# No corruptions
# AUC Score on the test set: 0.6046632338578648
# F1 Score on the test set: 0.6044164092582038
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5922679777314063
# F1 Score on the test set: 0.6001149748616764
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5901304040479203
# F1 Score on the test set: 0.5953379939546439
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6312290229349244
# F1 Score on the test set: 0.5376490622105589
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6046632338578648
# F1 Score on the test set: 0.6044164092582038
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6046632338578648
# F1 Score on the test set: 0.6044164092582038
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6046632338578648
# F1 Score on the test set: 0.6044164092582038
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6065955235552015
# F1 Score on the test set: 0.6069697984892906
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6044477207478857
# F1 Score on the test set: 0.6032896561334571
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6014092243353404
# F1 Score on the test set: 0.5987938603078429
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5970341321866572
# F1 Score on the test set: 0.583653357815369
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5791433648507127
# F1 Score on the test set: 0.5826421570793258
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.593323615274135
# F1 Score on the test set: 0.5587835046165287
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6012747728076195
# F1 Score on the test set: 0.5859231997835934
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.5912637766348273
# F1 Score on the test set: 0.5164956128932068
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6071832336922217
# F1 Score on the test set: 0.6086772031455516
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.601879489457217
# F1 Score on the test set: 0.5853939196108122
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6076929305338397
# F1 Score on the test set: 0.6081023065228488
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6030266893810334
# F1 Score on the test set: 0.5859446409212916
# Done!
# No corruptions
# AUC Score on the test set: 0.604436411775961
# F1 Score on the test set: 0.5882268278641336
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.586989963138095
# F1 Score on the test set: 0.5857694250567402
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5943095407659262
# F1 Score on the test set: 0.6046375082897659
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6009318925349459
# F1 Score on the test set: 0.5332700519112716
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.604436411775961
# F1 Score on the test set: 0.5882268278641336
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.604436411775961
# F1 Score on the test set: 0.5882268278641336
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.604436411775961
# F1 Score on the test set: 0.5882268278641336
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6012284768143729
# F1 Score on the test set: 0.5828517721182997
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5995443691074213
# F1 Score on the test set: 0.5812135992924287
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5996195899725889
# F1 Score on the test set: 0.5762314149578407
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5949244896559158
# F1 Score on the test set: 0.5432779370538194
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5932238318285431
# F1 Score on the test set: 0.5005361997156894
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5853020993613389
# F1 Score on the test set: 0.4506619923364226
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6058687878624216
# F1 Score on the test set: 0.6068227461658964
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6025803508860534
# F1 Score on the test set: 0.5907236752064338
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6012132886627455
# F1 Score on the test set: 0.5726515190471643
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.604023933814241
# F1 Score on the test set: 0.5955349290337749
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.5985958391409839
# F1 Score on the test set: 0.580478563573718
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6006221504608968
# F1 Score on the test set: 0.5868814096213443
# Done!
# No corruptions
# AUC Score on the test set: 0.6041262939359757
# F1 Score on the test set: 0.5966933927699885
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5977473733107592
# F1 Score on the test set: 0.6043404842846638
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5722230959974033
# F1 Score on the test set: 0.5784947272652371
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5911442403807421
# F1 Score on the test set: 0.5229064338123826
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6041262939359757
# F1 Score on the test set: 0.5966933927699885
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6041262939359757
# F1 Score on the test set: 0.5966933927699885
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6041262939359757
# F1 Score on the test set: 0.5966933927699885
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6049341242265436
# F1 Score on the test set: 0.5967590809654072
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.603790702730218
# F1 Score on the test set: 0.5940957328844627
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.604227630808874
# F1 Score on the test set: 0.5928644886617872
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5931353835555002
# F1 Score on the test set: 0.5436325441930197
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5962559063659116
# F1 Score on the test set: 0.5842671899150049
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.59967633551789
# F1 Score on the test set: 0.5912615828807455
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6043808178157303
# F1 Score on the test set: 0.5862946449712436
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6021799744579956
# F1 Score on the test set: 0.5797221721371295
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6061247904924791
# F1 Score on the test set: 0.598988288593502
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.5986188665439126
# F1 Score on the test set: 0.566735638267524
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6083788965213663
# F1 Score on the test set: 0.6132047933189603
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.5993143344116824
# F1 Score on the test set: 0.5837101591599746
# Done!
# No corruptions
# AUC Score on the test set: 0.6071632901088065
# F1 Score on the test set: 0.6106390312195746
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5940882393384014
# F1 Score on the test set: 0.6030495083446133
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5916235147299976
# F1 Score on the test set: 0.5961054408487171
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5873888637733575
# F1 Score on the test set: 0.5208538430330972
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6071632901088065
# F1 Score on the test set: 0.6106390312195746
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6071632901088065
# F1 Score on the test set: 0.6106390312195746
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6071632901088065
# F1 Score on the test set: 0.6106390312195746
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6051181376510824
# F1 Score on the test set: 0.6076214634346613
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6035263930531551
# F1 Score on the test set: 0.6046508687873744
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5999045830481502
# F1 Score on the test set: 0.5992679180842723
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5704741119807345
# F1 Score on the test set: 0.5345957282820428
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5675646816072245
# F1 Score on the test set: 0.5684759639775796
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5391702393119284
# F1 Score on the test set: 0.5265796967597938
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.5992365078794702
# F1 Score on the test set: 0.5665928900531721
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6045594466647098
# F1 Score on the test set: 0.5979676099306405
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6029680693570204
# F1 Score on the test set: 0.5940349745222814
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6050167202817653
# F1 Score on the test set: 0.5954219160114687
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6064055618090358
# F1 Score on the test set: 0.6115208717935384
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6067821799005211
# F1 Score on the test set: 0.6169759586803925
# Done!
# No corruptions
# AUC Score on the test set: 0.6092326092138949
# F1 Score on the test set: 0.6136738918514435
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5989046412690407
# F1 Score on the test set: 0.6086358176282414
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5944210499300139
# F1 Score on the test set: 0.5975427403614788
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5498740355849473
# F1 Score on the test set: 0.5020041710182555
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6092326092138949
# F1 Score on the test set: 0.6136738918514435
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6092326092138949
# F1 Score on the test set: 0.6136738918514435
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6092326092138949
# F1 Score on the test set: 0.6136738918514435
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6071183942878493
# F1 Score on the test set: 0.611186720900941
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6047711479372245
# F1 Score on the test set: 0.6070514126989206
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5983599400852007
# F1 Score on the test set: 0.5984568465781179
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5967831030738663
# F1 Score on the test set: 0.5842356252422363
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.592773875429093
# F1 Score on the test set: 0.5546229369932909
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5970703698551799
# F1 Score on the test set: 0.577944864941258
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6110213477844346
# F1 Score on the test set: 0.6189177445831653
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6107502806238208
# F1 Score on the test set: 0.6187467789672081
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6025368505966288
# F1 Score on the test set: 0.5895578821644822
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6031770786917388
# F1 Score on the test set: 0.5934314925196384
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6070281523334203
# F1 Score on the test set: 0.5972295885961983
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6022919422875089
# F1 Score on the test set: 0.5743379519754988
# Done!
# No corruptions
# AUC Score on the test set: 0.6021252245098307
# F1 Score on the test set: 0.578247577488448
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5873327642239563
# F1 Score on the test set: 0.5813855240434749
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5848749961012863
# F1 Score on the test set: 0.5938753220657582
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5576620144775635
# F1 Score on the test set: 0.5156790501723478
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6021252245098307
# F1 Score on the test set: 0.578247577488448
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6021252245098307
# F1 Score on the test set: 0.578247577488448
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6021252245098307
# F1 Score on the test set: 0.578247577488448
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6028087360435084
# F1 Score on the test set: 0.5776531672051396
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6001411589146897
# F1 Score on the test set: 0.5731836809912858
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6014668568425794
# F1 Score on the test set: 0.570956173117403
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5982707465459886
# F1 Score on the test set: 0.5659317815954933
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5947581332825056
# F1 Score on the test set: 0.5640450844952577
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.594048805640415
# F1 Score on the test set: 0.5855482093396327
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6086753889434973
# F1 Score on the test set: 0.6108230832983914
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6039992008649462
# F1 Score on the test set: 0.5959757556149009
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6035192853961291
# F1 Score on the test set: 0.5914845880430484
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6025496388736749
# F1 Score on the test set: 0.5824708891129652
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6005652874798495
# F1 Score on the test set: 0.5929165705436319
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.5969821490529459
# F1 Score on the test set: 0.5978797894270576
# Done!
# No corruptions
# AUC Score on the test set: 0.6023057734344863
# F1 Score on the test set: 0.5838486110318863
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5944570193329013
# F1 Score on the test set: 0.5933221161338146
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5815915455558747
# F1 Score on the test set: 0.5899516311071681
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5813950146571379
# F1 Score on the test set: 0.5256297430010841
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6023057734344863
# F1 Score on the test set: 0.5838486110318863
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6023057734344863
# F1 Score on the test set: 0.5838486110318863
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6023057734344863
# F1 Score on the test set: 0.5838486110318863
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6002658238231464
# F1 Score on the test set: 0.580223209496343
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6017386501452997
# F1 Score on the test set: 0.5801054045066715
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.597171077458702
# F1 Score on the test set: 0.5722944177708379
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5982687760358764
# F1 Score on the test set: 0.5739913132707177
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5965689656921938
# F1 Score on the test set: 0.5716736275806102
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5902852299528302
# F1 Score on the test set: 0.5093199582955463
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6029623100024717
# F1 Score on the test set: 0.5990659182461889
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6029389160835219
# F1 Score on the test set: 0.5832885657213764
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6042959873820408
# F1 Score on the test set: 0.5965314831037137
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.5952752401382075
# F1 Score on the test set: 0.5629272526930511
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6058687878624216
# F1 Score on the test set: 0.6068227461658964
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.5978086408662426
# F1 Score on the test set: 0.564860993509928
# Done!
# No corruptions
# AUC Score on the test set: 0.5980864288522012
# F1 Score on the test set: 0.5515134654815672
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.582455510085075
# F1 Score on the test set: 0.5630764204982053
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5644821408683321
# F1 Score on the test set: 0.5685302979305993
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5155095508869897
# F1 Score on the test set: 0.4962800776488646
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.5980864288522012
# F1 Score on the test set: 0.5515134654815672
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.5980864288522012
# F1 Score on the test set: 0.5515134654815672
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.5980864288522012
# F1 Score on the test set: 0.5515134654815672
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5951299379510611
# F1 Score on the test set: 0.5448354823902521
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5964404216584449
# F1 Score on the test set: 0.5420924839643408
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5950621411269275
# F1 Score on the test set: 0.5349913559092747
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5881391808404117
# F1 Score on the test set: 0.5859195074437021
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5518165914355999
# F1 Score on the test set: 0.5460769661184162
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.4956078541901541
# F1 Score on the test set: 0.4913856108012231
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6022089559482858
# F1 Score on the test set: 0.5770395571088361
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.60450363946105
# F1 Score on the test set: 0.5877666667038162
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6011772974088248
# F1 Score on the test set: 0.5646224762287446
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.5988871674413181
# F1 Score on the test set: 0.5963817645735919
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6024390628697642
# F1 Score on the test set: 0.5904484399359589
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6041658889842846
# F1 Score on the test set: 0.6053718312113312
# Done!
# No corruptions
# AUC Score on the test set: 0.6048365873181407
# F1 Score on the test set: 0.6011395228616901
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6005797262164394
# F1 Score on the test set: 0.6082909799047121
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5864480386801088
# F1 Score on the test set: 0.5928855353762119
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5338263718263718
# F1 Score on the test set: 0.5018856192386015
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6048365873181407
# F1 Score on the test set: 0.6011395228616901
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6048365873181407
# F1 Score on the test set: 0.6011395228616901
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6048365873181407
# F1 Score on the test set: 0.6011395228616901
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6045229819979622
# F1 Score on the test set: 0.6005787672393346
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6045361152160951
# F1 Score on the test set: 0.598842716831258
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6032350546787861
# F1 Score on the test set: 0.5950273418956872
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5958156099770959
# F1 Score on the test set: 0.5671732798229426
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5948525404226973
# F1 Score on the test set: 0.5672039914231588
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.6036427614945112
# F1 Score on the test set: 0.6068141481725801
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6033782811730473
# F1 Score on the test set: 0.5912089787697837
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.602375214360369
# F1 Score on the test set: 0.578790161286436
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.5940564179881447
# F1 Score on the test set: 0.5460133668064489
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6099807252760625
# F1 Score on the test set: 0.6142668601879718
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6033933246453738
# F1 Score on the test set: 0.5928223864006904
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6014739123262491
# F1 Score on the test set: 0.5543816101752155
# Done!
# No corruptions
# AUC Score on the test set: 0.6004632046753093
# F1 Score on the test set: 0.5882008516476038
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.595681449236882
# F1 Score on the test set: 0.597999853004544
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5688314085324052
# F1 Score on the test set: 0.5751733878999692
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5435177892682258
# F1 Score on the test set: 0.5051075822384872
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6004632046753093
# F1 Score on the test set: 0.5882008516476038
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6004632046753093
# F1 Score on the test set: 0.5882008516476038
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6004632046753093
# F1 Score on the test set: 0.5882008516476038
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5988717710694967
# F1 Score on the test set: 0.585628213974832
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5976918666223829
# F1 Score on the test set: 0.5827423288121911
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5993143344116824
# F1 Score on the test set: 0.5837101591599746
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5969813549786236
# F1 Score on the test set: 0.5534446749657271
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5939078353040966
# F1 Score on the test set: 0.5530560934717619
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5864248709002385
# F1 Score on the test set: 0.45533415527432275
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6025938709508092
# F1 Score on the test set: 0.5947910031132431
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6059103030111529
# F1 Score on the test set: 0.6072444156811987
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6031618808660906
# F1 Score on the test set: 0.5777233910631223
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6021717355718614
# F1 Score on the test set: 0.5733217610278163
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.602808970348107
# F1 Score on the test set: 0.583015905404245
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6050608174940519
# F1 Score on the test set: 0.5974808207905286
# Done!
# No corruptions
# AUC Score on the test set: 0.6089110731750607
# F1 Score on the test set: 0.614620439305824
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6042300287011024
# F1 Score on the test set: 0.6163358557562415
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.585564084370767
# F1 Score on the test set: 0.5887530475416497
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5986740381157857
# F1 Score on the test set: 0.5175281952368368
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6089110731750607
# F1 Score on the test set: 0.614620439305824
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6089110731750607
# F1 Score on the test set: 0.614620439305824
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6089110731750607
# F1 Score on the test set: 0.614620439305824
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6083788965213663
# F1 Score on the test set: 0.6132047933189603
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6033605925152832
# F1 Score on the test set: 0.6057191201653747
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5998138704742478
# F1 Score on the test set: 0.6001886825287255
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5964554713109627
# F1 Score on the test set: 0.5648642729385427
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5947589417698393
# F1 Score on the test set: 0.5468471347278328
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5890032585834941
# F1 Score on the test set: 0.4857933667763683
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6048715686502952
# F1 Score on the test set: 0.5951445224108562
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6020857025883637
# F1 Score on the test set: 0.5767686712202289
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6039159719084972
# F1 Score on the test set: 0.5981618178239334
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6048510313216195
# F1 Score on the test set: 0.602001571143334
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6038796898191691
# F1 Score on the test set: 0.6075032524099354
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6011891046435447
# F1 Score on the test set: 0.5911586747165676
# Done!
# No corruptions
# AUC Score on the test set: 0.6056628060957328
# F1 Score on the test set: 0.6061160805273436
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5940129080951866
# F1 Score on the test set: 0.6023761209597607
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5809862315328415
# F1 Score on the test set: 0.5866384685350354
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5715864305117213
# F1 Score on the test set: 0.5125607334045708
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6056628060957328
# F1 Score on the test set: 0.6061160805273436
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6056628060957328
# F1 Score on the test set: 0.6061160805273436
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6056628060957328
# F1 Score on the test set: 0.6061160805273436
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6017738554610674
# F1 Score on the test set: 0.6005956166714471
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6030043917245415
# F1 Score on the test set: 0.6011781834703234
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6009382345700798
# F1 Score on the test set: 0.5958668350910814
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5839922193780842
# F1 Score on the test set: 0.5710513214930341
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5697434060893932
# F1 Score on the test set: 0.5754833971341841
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5176030340875698
# F1 Score on the test set: 0.5075921289060423
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6045191030341676
# F1 Score on the test set: 0.5954814992544859
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6036457256735198
# F1 Score on the test set: 0.5938189729399316
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6018202076369581
# F1 Score on the test set: 0.5870174385530982
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.601896341065423
# F1 Score on the test set: 0.603972519890284
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.602033199899797
# F1 Score on the test set: 0.5813820630817683
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6062375788304148
# F1 Score on the test set: 0.593002303210947
# Done!
# No corruptions
# AUC Score on the test set: 0.6054620204871701
# F1 Score on the test set: 0.6000821914544044
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5949708879184862
# F1 Score on the test set: 0.6004250295687742
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5919654548335711
# F1 Score on the test set: 0.6005360535133529
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5835578642919663
# F1 Score on the test set: 0.518793029983629
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6054620204871701
# F1 Score on the test set: 0.6000821914544044
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6054620204871701
# F1 Score on the test set: 0.6000821914544044
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6054620204871701
# F1 Score on the test set: 0.6000821914544044
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6020832996709162
# ...
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6001418989075109
# F1 Score on the test set: 0.5969754073188521
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5991957428929058
# F1 Score on the test set: 0.5953069499889982
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5968454928324358
# F1 Score on the test set: 0.5919707771744215
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5915327284894498
# F1 Score on the test set: 0.5044361003073419
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5966275209081052
# F1 Score on the test set: 0.556185450813594
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.588859251458085
# F1 Score on the test set: 0.48882565286980206
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6062286777687866
# F1 Score on the test set: 0.6097509986267102
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6110521561104951
# F1 Score on the test set: 0.617694023876933
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6066954024587746
# F1 Score on the test set: 0.6063969083568387
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.5992267928998205
# F1 Score on the test set: 0.5936541302124758
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.5995210345210346
# F1 Score on the test set: 0.5970898328588776
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.5986938641492272
# F1 Score on the test set: 0.5762503444475062
# Done!
# No corruptions
# AUC Score on the test set: 0.6033329334991593
# F1 Score on the test set: 0.5916559675180366
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5927661547853855
# F1 Score on the test set: 0.5951485605475666
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5882941095152517
# F1 Score on the test set: 0.5973105677149029
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5490063136748458
# F1 Score on the test set: 0.5061147888885369
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6033329334991593
# F1 Score on the test set: 0.5916559675180366
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6033329334991593
# F1 Score on the test set: 0.5916559675180366
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6033329334991593
# F1 Score on the test set: 0.5916559675180366
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6029210558748024
# F1 Score on the test set: 0.5892114399933974
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6003984474165367
# F1 Score on the test set: 0.583565447370948
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5938635881552202
# F1 Score on the test set: 0.5737734646562388
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5767177949033637
# F1 Score on the test set: 0.5442188293850698
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5845811051693404
# F1 Score on the test set: 0.5933516332205135
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5303556658395369
# F1 Score on the test set: 0.5154603629572052
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.602871305749597
# F1 Score on the test set: 0.5957799944319533
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6059155532014621
# F1 Score on the test set: 0.5945532942074021
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6031661948780723
# F1 Score on the test set: 0.6014590988947677
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6020832902545439
# F1 Score on the test set: 0.5852145141881046
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.601275310272947
# F1 Score on the test set: 0.5770879526977089
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.5996684484927729
# F1 Score on the test set: 0.5957285156090009
# Done!
# No corruptions
# AUC Score on the test set: 0.6037227055799146
# F1 Score on the test set: 0.5896834379902773
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5908098768862109
# F1 Score on the test set: 0.5913827599646974
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5816205875189542
# F1 Score on the test set: 0.5898465150035392
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5631230880258528
# F1 Score on the test set: 0.516783677602503
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6037227055799146
# F1 Score on the test set: 0.5896834379902773
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6037227055799146
# F1 Score on the test set: 0.5896834379902773
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6037227055799146
# F1 Score on the test set: 0.5896834379902773
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.603035575113133
# F1 Score on the test set: 0.5883100469040633
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6012284768143729
# F1 Score on the test set: 0.5828517721182997
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6009562392732029
# F1 Score on the test set: 0.5803976639696653
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5989373561297527
# F1 Score on the test set: 0.561788884311309
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.594323811764014
# F1 Score on the test set: 0.5427160383924381
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5967927497290797
# F1 Score on the test set: 0.5574658964489474
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6043302081346869
# F1 Score on the test set: 0.5903301691153316
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6025693681007613
# F1 Score on the test set: 0.584394387282577
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6046786607543331
# F1 Score on the test set: 0.5999928828227603
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6048380987253708
# F1 Score on the test set: 0.5935205521412418
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6009269999251665
# F1 Score on the test set: 0.5975407043832045
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6062351390074381
# F1 Score on the test set: 0.6023615417079228
# Done!
# No corruptions
# AUC Score on the test set: 0.6050882466651802
# F1 Score on the test set: 0.5852527939724408
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5921886990589281
# F1 Score on the test set: 0.5894602072460902
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5798039645965913
# F1 Score on the test set: 0.5878491827529921
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5681992623073151
# F1 Score on the test set: 0.5149576930783102
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6050882466651802
# F1 Score on the test set: 0.5852527939724408
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6050882466651802
# F1 Score on the test set: 0.5852527939724408
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6050882466651802
# F1 Score on the test set: 0.5852527939724408
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6036356651860445
# F1 Score on the test set: 0.581508687877248
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.602476313522825
# F1 Score on the test set: 0.5783221318240774
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5953581984616758
# F1 Score on the test set: 0.5646518784921392
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5848363180591847
# F1 Score on the test set: 0.5798688160814516
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5791501215805037
# F1 Score on the test set: 0.5869602366473389
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5634732244587923
# F1 Score on the test set: 0.5451900352525534
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6021219901889219
# F1 Score on the test set: 0.5809206473476137
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.5969519976440562
# F1 Score on the test set: 0.5485862532056247
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6075090587132076
# F1 Score on the test set: 0.6102366929062715
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6061748999034773
# F1 Score on the test set: 0.6051171643743203
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6051616351567659
# F1 Score on the test set: 0.6052654808821791
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.5999313428721651
# F1 Score on the test set: 0.5782284887652644
# Done!
# No corruptions
# AUC Score on the test set: 0.6000594390446637
# F1 Score on the test set: 0.5834677238722394
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5860089434799516
# F1 Score on the test set: 0.58413456765963
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5880972145920532
# F1 Score on the test set: 0.5975465784616356
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5427833329779901
# F1 Score on the test set: 0.503651345597618
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6000594390446637
# F1 Score on the test set: 0.5834677238722394
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6000594390446637
# F1 Score on the test set: 0.5834677238722394
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6000594390446637
# F1 Score on the test set: 0.5834677238722394
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6000727892210005
# F1 Score on the test set: 0.5823005893562425
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5991869342948076
# F1 Score on the test set: 0.5792299452298849
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5993943465559186
# F1 Score on the test set: 0.5764192821722491
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5935364597959374
# F1 Score on the test set: 0.5642704843131282
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5949730483454543
# F1 Score on the test set: 0.551184645812976
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5873750763897669
# F1 Score on the test set: 0.3705156495638159
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6045191030341676
# F1 Score on the test set: 0.5954814992544859
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6078312802996346
# F1 Score on the test set: 0.619153499822218
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6074189151412351
# F1 Score on the test set: 0.5964152767827987
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.608719497486782
# F1 Score on the test set: 0.6051004402063207
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.607800572519084
# F1 Score on the test set: 0.6103858787424478
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6021492262678456
# F1 Score on the test set: 0.5939601498633644
# Done!
#      runtimes
# 0   13.469063
# 1   13.446205
# 2   13.322487
# 3   13.464326
# 4   14.807343
# 5   15.349074
# 6   16.225772
# 7   13.288579
# 8   13.721927
# 9   13.331983
# 10  13.360258
# 11  13.244810
# 12  13.473567
# 13  13.287309
# 14  13.258470
# 15  13.149489
# 16  13.084835
# 17  13.301521
# 18  13.411964
# 19  13.654975
# 20  13.479831
# 21  13.151125
# 22  13.376597
# 23  13.450043
# 24  13.649994
# 25  13.463071
# 26  13.367403
# 27  13.274060
# 28  13.319193
# 29  13.422939
