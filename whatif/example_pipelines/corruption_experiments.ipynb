# %%
from whatif.example_pipelines.helpful_reviews_data_corruptions_naive import do_review_corruption_naive, \
    measure_review_corruption_naive_exec_time
from whatif.utils.utils import get_project_root

def save_to_csv(df, filename):
    df.to_csv(f'{str(get_project_root())}/whatif/example_pipelines/datasets/sneakers/{filename}.csv',
              index=False)

# %%
corruption_qualitative_review_corruption_naive = do_review_corruption_naive(debug=True,
                                                                          corruption_percentages=[0.2, 0.5, 0.9],
                                                                          corrupt_features=["star_rating", "verified_purchase", "review_headline"])
save_to_csv(corruption_qualitative_review_corruption_naive, "corruption_qualitative_review_corruption_naive")
corruption_qualitative_review_corruption_naive
# Out:
# No corruptions
# AUC Score on the test set: 0.6068521490356086
# F1 Score on the test set: 0.6021648460941552
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5884473914644825
# F1 Score on the test set: 0.5927670623701152
# Corruptions in Train and test
# AUC Score on the test set: 0.5994499752259849
# F1 Score on the test set: 0.5839825302336594
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5858093738042482
# F1 Score on the test set: 0.5920962959514101
# Corruptions in Train and test
# AUC Score on the test set: 0.6009390184493548
# F1 Score on the test set: 0.5858233154981123
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5788534011682682
# F1 Score on the test set: 0.5251543712032962
# Corruptions in Train and test
# AUC Score on the test set: 0.5949043629952604
# F1 Score on the test set: 0.536809581630268
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6021485295717446
# F1 Score on the test set: 0.5859405896577139
# Corruptions in Train and test
# AUC Score on the test set: 0.604404762026751
# F1 Score on the test set: 0.5850925113243142
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6041140185688473
# F1 Score on the test set: 0.594205182555661
# Corruptions in Train and test
# AUC Score on the test set: 0.5998423173898695
# F1 Score on the test set: 0.5976475379214368
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6022501328918484
# F1 Score on the test set: 0.5785188233334245
# Corruptions in Train and test
# AUC Score on the test set: 0.6045286112157873
# F1 Score on the test set: 0.5992784967308722
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.603477893937209
# F1 Score on the test set: 0.5804953994090024
# Corruptions in Train and test
# AUC Score on the test set: 0.6028537650740304
# F1 Score on the test set: 0.5962131711597941
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6025477440423874
# F1 Score on the test set: 0.6033635453650785
# Corruptions in Train and test
# AUC Score on the test set: 0.5991506079864295
# F1 Score on the test set: 0.5917045402262794
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6016835400610399
# F1 Score on the test set: 0.5867437081303386
# Corruptions in Train and test
# AUC Score on the test set: 0.5991788963676514
# F1 Score on the test set: 0.5834378997576545
#     test_corruption  train_corruption  corruption_fraction            feature  \
# 0             False             False                  NaN               None
# 1             False              True                  0.2        star_rating
# 2              True              True                  0.2        star_rating
# 3             False              True                  0.5        star_rating
# 4              True              True                  0.5        star_rating
# 5             False              True                  0.9        star_rating
# 6              True              True                  0.9        star_rating
# 7             False              True                  0.2  verified_purchase
# 8              True              True                  0.2  verified_purchase
# 9             False              True                  0.5  verified_purchase
# 10             True              True                  0.5  verified_purchase
# 11            False              True                  0.9  verified_purchase
# 12             True              True                  0.9  verified_purchase
# 13            False              True                  0.2    review_headline
# 14             True              True                  0.2    review_headline
# 15            False              True                  0.5    review_headline
# 16             True              True                  0.5    review_headline
# 17            False              True                  0.9    review_headline
# 18             True              True                  0.9    review_headline
#
#      roc_auc        f1
# 0   0.606852  0.602165
# 1   0.588447  0.592767
# 2   0.599450  0.583983
# 3   0.585809  0.592096
# 4   0.600939  0.585823
# 5   0.578853  0.525154
# 6   0.594904  0.536810
# 7   0.602149  0.585941
# 8   0.604405  0.585093
# 9   0.604114  0.594205
# 10  0.599842  0.597648
# 11  0.602250  0.578519
# 12  0.604529  0.599278
# 13  0.603478  0.580495
# 14  0.602854  0.596213
# 15  0.602548  0.603364
# 16  0.599151  0.591705
# 17  0.601684  0.586744
# 18  0.599179  0.583438

# %%
review_corruption_naive_exec_times = measure_review_corruption_naive_exec_time(debug=True,
                                                                               corruption_percentages=[0.2, 0.5, 0.9],
                                                                               corrupt_features=["star_rating", "verified_purchase", "review_headline"],
                                                                               repeats=2)
save_to_csv(review_corruption_naive_exec_times, "review_corruption_naive_exec_times")
review_corruption_naive_exec_times
# Out:
# No corruptions
# AUC Score on the test set: 0.6003694496674372
# F1 Score on the test set: 0.5890739158497186
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5868463292596529
# F1 Score on the test set: 0.5809427864117728
# Corruptions in Train and test
# AUC Score on the test set: 0.5979645225399953
# F1 Score on the test set: 0.5753544677972895
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5869829584207711
# F1 Score on the test set: 0.5953650947589607
# Corruptions in Train and test
# AUC Score on the test set: 0.6004083243522215
# F1 Score on the test set: 0.5751949494675808
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5642207602339182
# F1 Score on the test set: 0.5208714748175272
# Corruptions in Train and test
# AUC Score on the test set: 0.5873379181195919
# F1 Score on the test set: 0.3761611060389972
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6049253845533082
# F1 Score on the test set: 0.592616702994447
# Corruptions in Train and test
# AUC Score on the test set: 0.6010740241412686
# F1 Score on the test set: 0.5780157037369655
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6090477942303565
# F1 Score on the test set: 0.6184030844566599
# Corruptions in Train and test
# AUC Score on the test set: 0.6040593090356123
# F1 Score on the test set: 0.6005981638827566
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6056612308788263
# F1 Score on the test set: 0.5956337393139193
# Corruptions in Train and test
# AUC Score on the test set: 0.620044392000383
# F1 Score on the test set: 0.6341168144814556
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6013577050094356
# F1 Score on the test set: 0.5934413321405942
# Corruptions in Train and test
# AUC Score on the test set: 0.6105658565127872
# F1 Score on the test set: 0.6100084616947565
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5943715798434567
# F1 Score on the test set: 0.5668553332453661
# Corruptions in Train and test
# AUC Score on the test set: 0.6062072985958173
# F1 Score on the test set: 0.60739165876078
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6013229957664137
# F1 Score on the test set: 0.6005746801696397
# Corruptions in Train and test
# AUC Score on the test set: 0.6043162676782132
# F1 Score on the test set: 0.591964579651894
# No corruptions
# AUC Score on the test set: 0.6027021537019193
# F1 Score on the test set: 0.588212508307445
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.589678289042887
# F1 Score on the test set: 0.5778275824191821
# Corruptions in Train and test
# AUC Score on the test set: 0.595380478448267
# F1 Score on the test set: 0.5711465604092404
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5814139492274897
# F1 Score on the test set: 0.5875904976968582
# Corruptions in Train and test
# AUC Score on the test set: 0.5897357353614021
# F1 Score on the test set: 0.5993789775420948
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5751402510392702
# F1 Score on the test set: 0.5203598212851664
# Corruptions in Train and test
# AUC Score on the test set: 0.5467565339964502
# F1 Score on the test set: 0.5196909977924834
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6018396995617094
# F1 Score on the test set: 0.5762271646873244
# Corruptions in Train and test
# AUC Score on the test set: 0.6013018716481853
# F1 Score on the test set: 0.5804827764288827
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6040513244346303
# F1 Score on the test set: 0.5950928928001646
# Corruptions in Train and test
# AUC Score on the test set: 0.602743111625364
# F1 Score on the test set: 0.5926025565411652
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6057604551459466
# F1 Score on the test set: 0.6083483668315046
# Corruptions in Train and test
# AUC Score on the test set: 0.6065931063971305
# F1 Score on the test set: 0.6083842599807103
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6072759979358872
# F1 Score on the test set: 0.6151528358433815
# Corruptions in Train and test
# AUC Score on the test set: 0.6036242304771445
# F1 Score on the test set: 0.5971700119864296
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6025496388736749
# F1 Score on the test set: 0.5824708891129652
# Corruptions in Train and test
# AUC Score on the test set: 0.6069955406602223
# F1 Score on the test set: 0.6065338499673437
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5987327654527037
# F1 Score on the test set: 0.5853553124313533
# Corruptions in Train and test
# AUC Score on the test set: 0.60268884217315
# F1 Score on the test set: 0.5858535938342948
#     runtimes
# 0  85.459883
# 1  81.543204
