# %%
from whatif.example_pipelines.helpful_reviews_data_corruptions_naive import do_review_corruption_naive, \
    measure_review_corruption_naive_exec_time
from whatif.utils.utils import get_project_root

def save_to_csv(df, filename):
    df.to_csv(f'{str(get_project_root())}/whatif/example_pipelines/datasets/sneakers/{filename}.csv',
              index=False)

# %%
corruption_screening_review_corruption_naive = do_review_corruption_naive(debug=True, corruption_percentages=[0.2, 0.5, 0.9])
corruption_screening_review_corruption_naive
# Out:
# No corruptions
# AUC Score on the test set: 0.6049415823653315
# F1 Score on the test set: 0.5942475204040552
# ____
# Now testing corruption of 20.0% of feature 0
# Corruptions in Test
# AUC Score on the test set: 0.6031386957106716
# F1 Score on the test set: 0.6006172690426678
# Corruptions in Train and test
# AUC Score on the test set: 0.6048560945441694
# F1 Score on the test set: 0.5902436048117249
# AUC Score on the test set: 0.6084975486197759
# F1 Score on the test set: 0.6071938726597915
# ____
# Now testing corruption of 50.0% of feature 0
# Corruptions in Test
# AUC Score on the test set: 0.6040659602398953
# F1 Score on the test set: 0.6010260847980973
# Corruptions in Train and test
# AUC Score on the test set: 0.6027827137344648
# F1 Score on the test set: 0.5889367816091954
# AUC Score on the test set: 0.6037540986091801
# F1 Score on the test set: 0.5983163802764445
# ____
# Now testing corruption of 90.0% of feature 0
# Corruptions in Test
# AUC Score on the test set: 0.6050102131585017
# F1 Score on the test set: 0.6022827191017177
# Corruptions in Train and test
# AUC Score on the test set: 0.6090257398693038
# F1 Score on the test set: 0.6139413027019035
# AUC Score on the test set: 0.6012220631563763
# F1 Score on the test set: 0.5711632600088472
# ____
# Now testing corruption of 20.0% of feature 1
# Corruptions in Test
# AUC Score on the test set: 0.60484235602719
# F1 Score on the test set: 0.6015711281607523
# Corruptions in Train and test
# AUC Score on the test set: 0.6023536358509203
# F1 Score on the test set: 0.586939531373923
# AUC Score on the test set: 0.6074603174603175
# F1 Score on the test set: 0.6069529948451965
# ____
# Now testing corruption of 50.0% of feature 1
# Corruptions in Test
# AUC Score on the test set: 0.5995495509145344
# F1 Score on the test set: 0.5733062717227784
# Corruptions in Train and test
# AUC Score on the test set: 0.6033221993669878
# F1 Score on the test set: 0.5937080643348537
# AUC Score on the test set: 0.6064368911524798
# F1 Score on the test set: 0.60438691354315
# ____
# Now testing corruption of 90.0% of feature 1
# Corruptions in Test
# AUC Score on the test set: 0.6103624094810984
# F1 Score on the test set: 0.6181596978641359
# Corruptions in Train and test
# AUC Score on the test set: 0.600618878743628
# F1 Score on the test set: 0.5920605482252983
# AUC Score on the test set: 0.6093765487164238
# F1 Score on the test set: 0.6150724945064616
# ____
# Now testing corruption of 20.0% of feature 2
# Corruptions in Test
# AUC Score on the test set: 0.6033221993669878
# F1 Score on the test set: 0.5937080643348537
# Corruptions in Train and test
# AUC Score on the test set: 0.6022059931119075
# F1 Score on the test set: 0.5823865929199076
# AUC Score on the test set: 0.6010968785898687
# F1 Score on the test set: 0.5825795156113218
# ____
# Now testing corruption of 50.0% of feature 2
# Corruptions in Test
# AUC Score on the test set: 0.607057383466999
# F1 Score on the test set: 0.6122652124130077
# Corruptions in Train and test
# AUC Score on the test set: 0.6064368911524798
# F1 Score on the test set: 0.60438691354315
# AUC Score on the test set: 0.6043072023270594
# F1 Score on the test set: 0.5867570385156515
# ____
# Now testing corruption of 90.0% of feature 2
# Corruptions in Test
# AUC Score on the test set: 0.6043072023270594
# F1 Score on the test set: 0.5867570385156515
# Corruptions in Train and test
# AUC Score on the test set: 0.6039771413152417
# F1 Score on the test set: 0.5964153746998648
# AUC Score on the test set: 0.6058687878624216
# F1 Score on the test set: 0.6068227461658964
# ____
# Now testing corruption of 20.0% of feature 3
# Corruptions in Test
# AUC Score on the test set: 0.5922479850238667
# F1 Score on the test set: 0.5965435239392923
# Corruptions in Train and test
# AUC Score on the test set: 0.5899973074851912
# F1 Score on the test set: 0.57942895861236
# AUC Score on the test set: 0.5893022428338226
# F1 Score on the test set: 0.5928059407410231
# ____
# Now testing corruption of 50.0% of feature 3
# Corruptions in Test
# AUC Score on the test set: 0.5861327426420333
# F1 Score on the test set: 0.5925905257101292
# Corruptions in Train and test
# AUC Score on the test set: 0.5933489633385249
# F1 Score on the test set: 0.5886981446179648
# AUC Score on the test set: 0.5831557331557331
# F1 Score on the test set: 0.5902358863026891
# ____
# Now testing corruption of 90.0% of feature 3
# Corruptions in Test
# AUC Score on the test set: 0.6111753614079195
# F1 Score on the test set: 0.5255148049069205
# Corruptions in Train and test
# AUC Score on the test set: 0.6068366007092618
# F1 Score on the test set: 0.5925946278110634
# AUC Score on the test set: 0.5510840026368541
# F1 Score on the test set: 0.5091793975388998
# ____
# Now testing corruption of 20.0% of feature 4
# Corruptions in Test
# AUC Score on the test set: 0.6020184769272361
# F1 Score on the test set: 0.586842349173641
# Corruptions in Train and test
# AUC Score on the test set: 0.6020359690298009
# F1 Score on the test set: 0.5880130440397779
# AUC Score on the test set: 0.5950236468733578
# F1 Score on the test set: 0.5631237300302967
# ____
# Now testing corruption of 50.0% of feature 4
# Corruptions in Test
# AUC Score on the test set: 0.5933603492893613
# F1 Score on the test set: 0.5763503387694328
# Corruptions in Train and test
# AUC Score on the test set: 0.6062409682475235
# F1 Score on the test set: 0.6027990006063557
# AUC Score on the test set: 0.593954200378849
# F1 Score on the test set: 0.5792368407724704
# ____
# Now testing corruption of 90.0% of feature 4
# Corruptions in Test
# AUC Score on the test set: 0.5860445005494271
# F1 Score on the test set: 0.5591193688056395
# Corruptions in Train and test
# AUC Score on the test set: 0.6070985119050955
# F1 Score on the test set: 0.6078231221514804
# AUC Score on the test set: 0.5879774359613069
# F1 Score on the test set: 0.5689673963216363
# ____
# Now testing corruption of 20.0% of feature 5
# Corruptions in Test
# AUC Score on the test set: 0.6053464226513149
# F1 Score on the test set: 0.5838415417726167
# Corruptions in Train and test
# AUC Score on the test set: 0.6047605902717873
# F1 Score on the test set: 0.607998745658133
# AUC Score on the test set: 0.6005373568113103
# F1 Score on the test set: 0.5909240106725842
# ____
# Now testing corruption of 50.0% of feature 5
# Corruptions in Test
# AUC Score on the test set: 0.6093894893265825
# F1 Score on the test set: 0.6145204449695141
# Corruptions in Train and test
# AUC Score on the test set: 0.5995764823119083
# F1 Score on the test set: 0.5800430743221868
# AUC Score on the test set: 0.6037970187692754
# F1 Score on the test set: 0.6021629286963226
# ____
# Now testing corruption of 90.0% of feature 5
# Corruptions in Test
# AUC Score on the test set: 0.5970730181383528
# F1 Score on the test set: 0.5647317470581374
# Corruptions in Train and test
# AUC Score on the test set: 0.5986442777308163
# F1 Score on the test set: 0.6024151248454308
# AUC Score on the test set: 0.6018829571898122
# F1 Score on the test set: 0.5929727812561622
# ____
# Now testing corruption of 20.0% of feature 6
# Corruptions in Test
# AUC Score on the test set: 0.6025693681007613
# F1 Score on the test set: 0.584394387282577
# Corruptions in Train and test
# AUC Score on the test set: 0.5995118549511855
# F1 Score on the test set: 0.5954507658102135
# AUC Score on the test set: 0.6094423902224981
# F1 Score on the test set: 0.622103848025867
# ____
# Now testing corruption of 50.0% of feature 6
# Corruptions in Test
# AUC Score on the test set: 0.5899355782222557
# F1 Score on the test set: 0.5932510270460847
# Corruptions in Train and test
# AUC Score on the test set: 0.60410290296296
# F1 Score on the test set: 0.6158772665775233
# AUC Score on the test set: 0.5976568210493645
# F1 Score on the test set: 0.5965522200301858
# ____
# Now testing corruption of 90.0% of feature 6
# Corruptions in Test
# AUC Score on the test set: 0.5937290697491338
# F1 Score on the test set: 0.5987935497315741
# Corruptions in Train and test
# AUC Score on the test set: 0.6009768114820532
# F1 Score on the test set: 0.5784775229769897
# AUC Score on the test set: 0.5957691366624472
# F1 Score on the test set: 0.6031139177947836
#     test_corruption  train_corruption  corruption_fraction  feature_num  \
# 0             False             False                  NaN          NaN
# 1             False              True                  0.2          0.0
# 2              True              True                  0.2          0.0
# 3             False              True                  0.5          0.0
# 4              True              True                  0.5          0.0
# 5             False              True                  0.9          0.0
# 6              True              True                  0.9          0.0
# 7             False              True                  0.2          1.0
# 8              True              True                  0.2          1.0
# 9             False              True                  0.5          1.0
# 10             True              True                  0.5          1.0
# 11            False              True                  0.9          1.0
# 12             True              True                  0.9          1.0
# 13            False              True                  0.2          2.0
# 14             True              True                  0.2          2.0
# 15            False              True                  0.5          2.0
# 16             True              True                  0.5          2.0
# 17            False              True                  0.9          2.0
# 18             True              True                  0.9          2.0
# 19            False              True                  0.2          3.0
# 20             True              True                  0.2          3.0
# 21            False              True                  0.5          3.0
# 22             True              True                  0.5          3.0
# 23            False              True                  0.9          3.0
# 24             True              True                  0.9          3.0
# 25            False              True                  0.2          4.0
# 26             True              True                  0.2          4.0
# 27            False              True                  0.5          4.0
# 28             True              True                  0.5          4.0
# 29            False              True                  0.9          4.0
# 30             True              True                  0.9          4.0
# 31            False              True                  0.2          5.0
# 32             True              True                  0.2          5.0
# 33            False              True                  0.5          5.0
# 34             True              True                  0.5          5.0
# 35            False              True                  0.9          5.0
# 36             True              True                  0.9          5.0
# 37            False              True                  0.2          6.0
# 38             True              True                  0.2          6.0
# 39            False              True                  0.5          6.0
# 40             True              True                  0.5          6.0
# 41            False              True                  0.9          6.0
# 42             True              True                  0.9          6.0
#
#      roc_auc        f1
# 0   0.604942  0.594248
# 1   0.603139  0.600617
# 2   0.608498  0.607194
# 3   0.604066  0.601026
# 4   0.603754  0.598316
# 5   0.605010  0.602283
# 6   0.601222  0.571163
# 7   0.604842  0.601571
# 8   0.607460  0.606953
# 9   0.599550  0.573306
# 10  0.606437  0.604387
# 11  0.610362  0.618160
# 12  0.609377  0.615072
# 13  0.603322  0.593708
# 14  0.601097  0.582580
# 15  0.607057  0.612265
# 16  0.604307  0.586757
# 17  0.604307  0.586757
# 18  0.605869  0.606823
# 19  0.592248  0.596544
# 20  0.589302  0.592806
# 21  0.586133  0.592591
# 22  0.583156  0.590236
# 23  0.611175  0.525515
# 24  0.551084  0.509179
# 25  0.602018  0.586842
# 26  0.595024  0.563124
# 27  0.593360  0.576350
# 28  0.593954  0.579237
# 29  0.586045  0.559119
# 30  0.587977  0.568967
# 31  0.605346  0.583842
# 32  0.600537  0.590924
# 33  0.609389  0.614520
# 34  0.603797  0.602163
# 35  0.597073  0.564732
# 36  0.601883  0.592973
# 37  0.602569  0.584394
# 38  0.609442  0.622104
# 39  0.589936  0.593251
# 40  0.597657  0.596552
# 41  0.593729  0.598794
# 42  0.595769  0.603114

# %%
review_corruption_naive_exec_times = measure_review_corruption_naive_exec_time(debug=True, corruption_percentages=[0.2, 0.5, 0.9], repeats=3)
save_to_csv(review_corruption_naive_exec_times, "review_corruption_naive_exec_times")
review_corruption_naive_exec_times
# Out:
# No corruptions
# AUC Score on the test set: 0.605361650442517
# F1 Score on the test set: 0.6037045841718839
# ____
# Now testing corruption of 20.0% of feature 0
# Corruptions in Test
# AUC Score on the test set: 0.6012284768143729
# F1 Score on the test set: 0.5828517721182997
# Corruptions in Train and test
# AUC Score on the test set: 0.6019431142958992
# F1 Score on the test set: 0.6030469244107509
# ____
# Now testing corruption of 50.0% of feature 0
# Corruptions in Test
# AUC Score on the test set: 0.6046983596093425
# F1 Score on the test set: 0.5986848007884634
# Corruptions in Train and test
# AUC Score on the test set: 0.6025069639306202
# F1 Score on the test set: 0.5817367718468136
# ____
# Now testing corruption of 90.0% of feature 0
# Corruptions in Test
# AUC Score on the test set: 0.6016112305861552
# F1 Score on the test set: 0.5798338510483729
# Corruptions in Train and test
# AUC Score on the test set: 0.6068770153634251
# F1 Score on the test set: 0.6003860659974746
# ____
# Now testing corruption of 20.0% of feature 1
# Corruptions in Test
# AUC Score on the test set: 0.6043729517557139
# F1 Score on the test set: 0.59520408222091
# Corruptions in Train and test
# AUC Score on the test set: 0.603756820013214
# F1 Score on the test set: 0.600891466018514
# ____
# Now testing corruption of 50.0% of feature 1
# Corruptions in Test
# AUC Score on the test set: 0.6062839671971884
# F1 Score on the test set: 0.6092059771617783
# Corruptions in Train and test
# AUC Score on the test set: 0.6033223059737152
# F1 Score on the test set: 0.5966135830880958
# ____
# Now testing corruption of 90.0% of feature 1
# Corruptions in Test
# AUC Score on the test set: 0.5982321165092328
# F1 Score on the test set: 0.5479154005105141
# Corruptions in Train and test
# AUC Score on the test set: 0.6073350666307269
# F1 Score on the test set: 0.6099502198000855
# ____
# Now testing corruption of 20.0% of feature 2
# Corruptions in Test
# AUC Score on the test set: 0.6025066637455727
# F1 Score on the test set: 0.5883878168527945
# Corruptions in Train and test
# AUC Score on the test set: 0.6027807207870206
# F1 Score on the test set: 0.5921611280351927
# ____
# Now testing corruption of 50.0% of feature 2
# Corruptions in Test
# AUC Score on the test set: 0.6055996739414241
# F1 Score on the test set: 0.5965328054866393
# Corruptions in Train and test
# AUC Score on the test set: 0.6056315362248226
# F1 Score on the test set: 0.5939993611672596
# ____
# Now testing corruption of 90.0% of feature 2
# Corruptions in Test
# AUC Score on the test set: 0.6037031885133151
# F1 Score on the test set: 0.5861224671275415
# Corruptions in Train and test
# AUC Score on the test set: 0.6052792390669004
# F1 Score on the test set: 0.5964244328226573
# ____
# Now testing corruption of 20.0% of feature 3
# Corruptions in Test
# AUC Score on the test set: 0.5887217528471218
# F1 Score on the test set: 0.5916410806374766
# Corruptions in Train and test
# AUC Score on the test set: 0.589062106210621
# F1 Score on the test set: 0.5675289487194113
# ____
# Now testing corruption of 50.0% of feature 3
# Corruptions in Test
# AUC Score on the test set: 0.5816727664361716
# F1 Score on the test set: 0.5897076024981667
# Corruptions in Train and test
# AUC Score on the test set: 0.5981562338440118
# F1 Score on the test set: 0.577065981528667
# ____
# Now testing corruption of 90.0% of feature 3
# Corruptions in Test
# AUC Score on the test set: 0.5662782459434706
# F1 Score on the test set: 0.5225747457632237
# Corruptions in Train and test
# AUC Score on the test set: 0.5970341321866572
# F1 Score on the test set: 0.583653357815369
# ____
# Now testing corruption of 20.0% of feature 4
# Corruptions in Test
# AUC Score on the test set: 0.6009311150319052
# F1 Score on the test set: 0.5979560024348647
# Corruptions in Train and test
# AUC Score on the test set: 0.6054875630347328
# F1 Score on the test set: 0.6072293849747605
# ____
# Now testing corruption of 50.0% of feature 4
# Corruptions in Test
# AUC Score on the test set: 0.5951170430997678
# F1 Score on the test set: 0.5787301630725583
# Corruptions in Train and test
# AUC Score on the test set: 0.6152157815439661
# F1 Score on the test set: 0.6280009598782959
# ____
# Now testing corruption of 90.0% of feature 4
# Corruptions in Test
# AUC Score on the test set: 0.585355490510811
# F1 Score on the test set: 0.546968022075582
# Corruptions in Train and test
# AUC Score on the test set: 0.5980908559579023
# F1 Score on the test set: 0.5756241388130395
# ____
# Now testing corruption of 20.0% of feature 5
# Corruptions in Test
# AUC Score on the test set: 0.5984133311496551
# F1 Score on the test set: 0.5794912282038389
# Corruptions in Train and test
# AUC Score on the test set: 0.6059984732995813
# F1 Score on the test set: 0.606684003502215
# ____
# Now testing corruption of 50.0% of feature 5
# Corruptions in Test
# AUC Score on the test set: 0.6039094777244406
# F1 Score on the test set: 0.585935529667408
# Corruptions in Train and test
# AUC Score on the test set: 0.5997402001579071
# F1 Score on the test set: 0.5904080171796706
# ____
# Now testing corruption of 90.0% of feature 5
# Corruptions in Test
# AUC Score on the test set: 0.6021246139989707
# F1 Score on the test set: 0.5943934601683679
# Corruptions in Train and test
# AUC Score on the test set: 0.6049415823653315
# F1 Score on the test set: 0.5942475204040552
# ____
# Now testing corruption of 20.0% of feature 6
# Corruptions in Test
# AUC Score on the test set: 0.5929253811510556
# F1 Score on the test set: 0.559064638064867
# Corruptions in Train and test
# AUC Score on the test set: 0.6025347961047001
# F1 Score on the test set: 0.600754383861271
# ____
# Now testing corruption of 50.0% of feature 6
# Corruptions in Test
# AUC Score on the test set: 0.6027568551901927
# F1 Score on the test set: 0.6063078312804491
# Corruptions in Train and test
# AUC Score on the test set: 0.597486653298263
# F1 Score on the test set: 0.5817639346120358
# ____
# Now testing corruption of 90.0% of feature 6
# Corruptions in Test
# AUC Score on the test set: 0.5969884841526633
# F1 Score on the test set: 0.6078002721433886
# Corruptions in Train and test
# AUC Score on the test set: 0.5948268255018752
# F1 Score on the test set: 0.5440403820207251
# No corruptions
# AUC Score on the test set: 0.6024390628697642
# F1 Score on the test set: 0.5904484399359589
# ____
# Now testing corruption of 20.0% of feature 0
# Corruptions in Test
# AUC Score on the test set: 0.6027827137344648
# F1 Score on the test set: 0.5889367816091954
# Corruptions in Train and test
# AUC Score on the test set: 0.60445687169926
# F1 Score on the test set: 0.585830981712991
# ____
# Now testing corruption of 50.0% of feature 0
# Corruptions in Test
# AUC Score on the test set: 0.6030346291263322
# F1 Score on the test set: 0.5808874332041875
# Corruptions in Train and test
# AUC Score on the test set: 0.6008817692822129
# F1 Score on the test set: 0.5655936835712116
# ____
# Now testing corruption of 90.0% of feature 0
# Corruptions in Test
# AUC Score on the test set: 0.60074985487494
# F1 Score on the test set: 0.5745328507059844
# Corruptions in Train and test
# AUC Score on the test set: 0.6027736443662853
# F1 Score on the test set: 0.5731767101045451
# ____
# Now testing corruption of 20.0% of feature 1
# Corruptions in Test
# AUC Score on the test set: 0.6057752503318639
# F1 Score on the test set: 0.6023910913140312
# Corruptions in Train and test
# AUC Score on the test set: 0.6148074347229342
# F1 Score on the test set: 0.6271881087626583
# ____
# Now testing corruption of 50.0% of feature 1
# Corruptions in Test
# AUC Score on the test set: 0.602743111625364
# F1 Score on the test set: 0.5926025565411652
# Corruptions in Train and test
# AUC Score on the test set: 0.6045883784699757
# F1 Score on the test set: 0.5861047538864712
# ____
# Now testing corruption of 90.0% of feature 1
# Corruptions in Test
# AUC Score on the test set: 0.6056764472623809
# F1 Score on the test set: 0.5981513016688896
# Corruptions in Train and test
# AUC Score on the test set: 0.6020535535347143
# F1 Score on the test set: 0.5794506362866924
# ____
# Now testing corruption of 20.0% of feature 2
# Corruptions in Test
# AUC Score on the test set: 0.6022910502428862
# F1 Score on the test set: 0.5819262760331751
# Corruptions in Train and test
# AUC Score on the test set: 0.6068150908096006
# F1 Score on the test set: 0.6090918951050035
# ____
# Now testing corruption of 50.0% of feature 2
# Corruptions in Test
# AUC Score on the test set: 0.6038954340768667
# F1 Score on the test set: 0.5911373741039833
# Corruptions in Train and test
# AUC Score on the test set: 0.6064597077449092
# F1 Score on the test set: 0.5986522308200297
# ____
# Now testing corruption of 90.0% of feature 2
# Corruptions in Test
# AUC Score on the test set: 0.6037067842511228
# F1 Score on the test set: 0.5913117217216046
# Corruptions in Train and test
# AUC Score on the test set: 0.6004143315251596
# F1 Score on the test set: 0.5685335890984176
# ____
# Now testing corruption of 20.0% of feature 3
# Corruptions in Test
# AUC Score on the test set: 0.5905653578604714
# F1 Score on the test set: 0.5954705021940516
# Corruptions in Train and test
# AUC Score on the test set: 0.5967568430695275
# F1 Score on the test set: 0.5831095568184184
# ____
# Now testing corruption of 50.0% of feature 3
# Corruptions in Test
# AUC Score on the test set: 0.5836336095016916
# F1 Score on the test set: 0.5918702422554049
# Corruptions in Train and test
# AUC Score on the test set: 0.5590591674335517
# F1 Score on the test set: 0.5587255305887449
# ____
# Now testing corruption of 90.0% of feature 3
# Corruptions in Test
# AUC Score on the test set: 0.580574621243827
# F1 Score on the test set: 0.5212790040729229
# Corruptions in Train and test
# AUC Score on the test set: 0.5854147315843349
# F1 Score on the test set: 0.40213031451079445
# ____
# Now testing corruption of 20.0% of feature 4
# Corruptions in Test
# AUC Score on the test set: 0.6026639122042207
# F1 Score on the test set: 0.5972268250953131
# Corruptions in Train and test
# AUC Score on the test set: 0.6135076010529117
# F1 Score on the test set: 0.6267784479869788
# ____
# Now testing corruption of 50.0% of feature 4
# Corruptions in Test
# AUC Score on the test set: 0.5987905654535731
# F1 Score on the test set: 0.5981095681708587
# Corruptions in Train and test
# AUC Score on the test set: 0.6055978735929501
# F1 Score on the test set: 0.605267754465979
# ____
# Now testing corruption of 90.0% of feature 4
# Corruptions in Test
# AUC Score on the test set: 0.5806019406244977
# F1 Score on the test set: 0.5269560535558186
# Corruptions in Train and test
# AUC Score on the test set: 0.5982592692101021
# F1 Score on the test set: 0.5900531466553104
# ____
# Now testing corruption of 20.0% of feature 5
# Corruptions in Test
# AUC Score on the test set: 0.5959581229365402
# F1 Score on the test set: 0.547983615965071
# Corruptions in Train and test
# AUC Score on the test set: 0.6056221306028754
# F1 Score on the test set: 0.5999222598827669
# ____
# Now testing corruption of 50.0% of feature 5
# Corruptions in Test
# AUC Score on the test set: 0.6023600715220101
# F1 Score on the test set: 0.6000561227363715
# Corruptions in Train and test
# AUC Score on the test set: 0.6020661623574574
# F1 Score on the test set: 0.5907830957108625
# ____
# Now testing corruption of 90.0% of feature 5
# Corruptions in Test
# AUC Score on the test set: 0.5996195899725889
# F1 Score on the test set: 0.5762314149578407
# Corruptions in Train and test
# AUC Score on the test set: 0.602978911957533
# F1 Score on the test set: 0.6003369078433789
# ____
# Now testing corruption of 20.0% of feature 6
# Corruptions in Test
# AUC Score on the test set: 0.6039171048960948
# F1 Score on the test set: 0.5895048860270179
# Corruptions in Train and test
# AUC Score on the test set: 0.5979758878457627
# F1 Score on the test set: 0.5698097877631075
# ____
# Now testing corruption of 50.0% of feature 6
# Corruptions in Test
# AUC Score on the test set: 0.5955541936711553
# F1 Score on the test set: 0.5933339588937312
# Corruptions in Train and test
# AUC Score on the test set: 0.6054010180085434
# F1 Score on the test set: 0.5971488067693529
# ____
# Now testing corruption of 90.0% of feature 6
# Corruptions in Test
# AUC Score on the test set: 0.5936402484825107
# F1 Score on the test set: 0.591939255219117
# Corruptions in Train and test
# AUC Score on the test set: 0.5970608498911268
# F1 Score on the test set: 0.5863251879311866
# No corruptions
# AUC Score on the test set: 0.6051761584883414
# F1 Score on the test set: 0.5891398504187585
# ____
# Now testing corruption of 20.0% of feature 0
# Corruptions in Test
# AUC Score on the test set: 0.6035370036711838
# F1 Score on the test set: 0.5930986886603993
# Corruptions in Train and test
# AUC Score on the test set: 0.607731330792485
# F1 Score on the test set: 0.6124672915472478
# ____
# Now testing corruption of 50.0% of feature 0
# Corruptions in Test
# AUC Score on the test set: 0.6061521356639523
# F1 Score on the test set: 0.6046867289446922
# Corruptions in Train and test
# AUC Score on the test set: 0.6052965155237882
# F1 Score on the test set: 0.6051258683445413
# ____
# Now testing corruption of 90.0% of feature 0
# Corruptions in Test
# AUC Score on the test set: 0.6052534321713476
# F1 Score on the test set: 0.5968705858760256
# Corruptions in Train and test
# AUC Score on the test set: 0.6071623204108048
# F1 Score on the test set: 0.6022834417232792
# ____
# Now testing corruption of 20.0% of feature 1
# Corruptions in Test
# AUC Score on the test set: 0.6050495694395102
# F1 Score on the test set: 0.5949738099108122
# Corruptions in Train and test
# AUC Score on the test set: 0.6078580503284395
# F1 Score on the test set: 0.610810190092573
# ____
# Now testing corruption of 50.0% of feature 1
# Corruptions in Test
# AUC Score on the test set: 0.6093738450979357
# F1 Score on the test set: 0.6156190932059801
# Corruptions in Train and test
# AUC Score on the test set: 0.604840248489743
# F1 Score on the test set: 0.5878538928371084
# ____
# Now testing corruption of 90.0% of feature 1
# Corruptions in Test
# AUC Score on the test set: 0.5999177919611246
# F1 Score on the test set: 0.5689468197400926
# Corruptions in Train and test
# AUC Score on the test set: 0.60445687169926
# F1 Score on the test set: 0.585830981712991
# ____
# Now testing corruption of 20.0% of feature 2
# Corruptions in Test
# AUC Score on the test set: 0.6045958398341791
# F1 Score on the test set: 0.6053911067035102
# Corruptions in Train and test
# AUC Score on the test set: 0.6054131273251409
# F1 Score on the test set: 0.6077775422231645
# ____
# Now testing corruption of 50.0% of feature 2
# Corruptions in Test
# AUC Score on the test set: 0.6088248163884709
# F1 Score on the test set: 0.6142023034917851
# Corruptions in Train and test
# AUC Score on the test set: 0.6010087520954546
# F1 Score on the test set: 0.5758104495777354
# ____
# Now testing corruption of 90.0% of feature 2
# Corruptions in Test
# AUC Score on the test set: 0.5995669761836901
# F1 Score on the test set: 0.5681408441122194
# Corruptions in Train and test
# AUC Score on the test set: 0.602408040030683
# F1 Score on the test set: 0.6013055738332661
# ____
# Now testing corruption of 20.0% of feature 3
# Corruptions in Test
# AUC Score on the test set: 0.5981238273921201
# F1 Score on the test set: 0.6032332048000257
# Corruptions in Train and test
# AUC Score on the test set: 0.5956676510346671
# F1 Score on the test set: 0.5482115832730285
# ____
# Now testing corruption of 50.0% of feature 3
# Corruptions in Test
# AUC Score on the test set: 0.5800609820716138
# F1 Score on the test set: 0.5881335974213976
# Corruptions in Train and test
# AUC Score on the test set: 0.6002681146946673
# F1 Score on the test set: 0.5856191250379029
# ____
# Now testing corruption of 90.0% of feature 3
# Corruptions in Test
# AUC Score on the test set: 0.6032203797164144
# F1 Score on the test set: 0.5229479208352448
# Corruptions in Train and test
# AUC Score on the test set: 0.5862600645351737
# F1 Score on the test set: 0.471957245983589
# ____
# Now testing corruption of 20.0% of feature 4
# Corruptions in Test
# AUC Score on the test set: 0.5962966988071591
# F1 Score on the test set: 0.5675168280449358
# Corruptions in Train and test
# AUC Score on the test set: 0.599369072013563
# F1 Score on the test set: 0.59721745505325
# ____
# Now testing corruption of 50.0% of feature 4
# Corruptions in Test
# AUC Score on the test set: 0.6025012545615418
# F1 Score on the test set: 0.5994967641431889
# Corruptions in Train and test
# AUC Score on the test set: 0.6024225493594566
# F1 Score on the test set: 0.5949476597457073
# ____
# Now testing corruption of 90.0% of feature 4
# Corruptions in Test
# AUC Score on the test set: 0.6065286430941015
# F1 Score on the test set: 0.6187509364912813
# Corruptions in Train and test
# AUC Score on the test set: 0.6032296422018657
# F1 Score on the test set: 0.6027128284458171
# ____
# Now testing corruption of 20.0% of feature 5
# Corruptions in Test
# AUC Score on the test set: 0.6034591160251492
# F1 Score on the test set: 0.601178464601053
# Corruptions in Train and test
# AUC Score on the test set: 0.6024549551695553
# F1 Score on the test set: 0.5920505775379221
# ____
# Now testing corruption of 50.0% of feature 5
# Corruptions in Test
# AUC Score on the test set: 0.6049253845533082
# F1 Score on the test set: 0.592616702994447
# Corruptions in Train and test
# AUC Score on the test set: 0.6014833308066391
# F1 Score on the test set: 0.594147824751834
# ____
# Now testing corruption of 90.0% of feature 5
# Corruptions in Test
# AUC Score on the test set: 0.5906129727587677
# F1 Score on the test set: 0.5576376545667752
# Corruptions in Train and test
# AUC Score on the test set: 0.5986755171667405
# F1 Score on the test set: 0.5800330945291083
# ____
# Now testing corruption of 20.0% of feature 6
# Corruptions in Test
# AUC Score on the test set: 0.6046623133756399
# F1 Score on the test set: 0.613020899470153
# Corruptions in Train and test
# AUC Score on the test set: 0.6027515025460514
# F1 Score on the test set: 0.5796047314671957
# ____
# Now testing corruption of 50.0% of feature 6
# Corruptions in Test
# AUC Score on the test set: 0.5985663020320637
# F1 Score on the test set: 0.6007906976744186
# Corruptions in Train and test
# AUC Score on the test set: 0.5995264084095941
# F1 Score on the test set: 0.5890001624152114
# ____
# Now testing corruption of 90.0% of feature 6
# Corruptions in Test
# AUC Score on the test set: 0.5994109576336836
# F1 Score on the test set: 0.6104150358773647
# Corruptions in Train and test
# AUC Score on the test set: 0.6007688113592755
# F1 Score on the test set: 0.5968456782834486
#      runtimes
# 0  191.680549
# 1  189.538728
# 2  183.902066
