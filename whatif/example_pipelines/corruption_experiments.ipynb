# %%
from whatif.example_pipelines.helpful_reviews_data_corruptions_naive import do_review_corruption_naive, \
    measure_review_corruption_naive_exec_time
from whatif.example_pipelines.helpful_reviews_data_corruptions_opt import do_review_corruption_opt, \
    measure_review_corruption_opt_exec_time
from whatif.utils.utils import get_project_root

def save_to_csv(df, filename):
    df.to_csv(f'{str(get_project_root())}/whatif/example_pipelines/datasets/sneakers/{filename}.csv',
              index=False)

# %%
corruption_qualitative_review_corruption_naive = do_review_corruption_naive(debug=True,
                                                                          corruption_percentages=[0.2, 0.5, 0.9],
                                                                          corrupt_features=["star_rating", "verified_purchase", "review_headline"])
save_to_csv(corruption_qualitative_review_corruption_naive, "corruption_qualitative_review_corruption_naive")
corruption_qualitative_review_corruption_naive
# Out:
# No corruptions
# AUC Score on the test set: 0.6036073700735355
# F1 Score on the test set: 0.6010357570065537
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6037904177001922
# F1 Score on the test set: 0.5970126636359387
# Corruptions in Train and test
# AUC Score on the test set: 0.6035756078670548
# F1 Score on the test set: 0.5926538015590415
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6022181496461072
# F1 Score on the test set: 0.5959635975740661
# Corruptions in Train and test
# AUC Score on the test set: 0.604041857611654
# F1 Score on the test set: 0.586209258953832
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6020941644548513
# F1 Score on the test set: 0.587565243372578
# Corruptions in Train and test
# AUC Score on the test set: 0.6039075356675843
# F1 Score on the test set: 0.5985954303879069
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6051079597060524
# F1 Score on the test set: 0.5884029740534209
# Corruptions in Train and test
# AUC Score on the test set: 0.6026257938446508
# F1 Score on the test set: 0.5874873958754809
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6049889659520806
# F1 Score on the test set: 0.6005529007876514
# Corruptions in Train and test
# AUC Score on the test set: 0.6017819149496981
# F1 Score on the test set: 0.5902327613308346
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6032121868512184
# F1 Score on the test set: 0.5929894714906541
# Corruptions in Train and test
# AUC Score on the test set: 0.6012402278832895
# F1 Score on the test set: 0.597681517949054
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6035311572700297
# F1 Score on the test set: 0.5955821454168989
# Corruptions in Train and test
# AUC Score on the test set: 0.6010531932064779
# F1 Score on the test set: 0.5676339212996311
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6016230508997773
# F1 Score on the test set: 0.5871910314875871
# Corruptions in Train and test
# AUC Score on the test set: 0.6022882143410252
# F1 Score on the test set: 0.5850336280300293
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6027600858019271
# F1 Score on the test set: 0.5853977380191673
# Corruptions in Train and test
# AUC Score on the test set: 0.6034675538009193
# F1 Score on the test set: 0.5939847668268218
#     test_corruption  train_corruption  corruption_fraction            feature  \
# 0             False             False                  NaN               None
# 1             False              True                  0.2        star_rating
# 2              True              True                  0.2        star_rating
# 3             False              True                  0.5        star_rating
# 4              True              True                  0.5        star_rating
# 5             False              True                  0.9        star_rating
# 6              True              True                  0.9        star_rating
# 7             False              True                  0.2  verified_purchase
# 8              True              True                  0.2  verified_purchase
# 9             False              True                  0.5  verified_purchase
# 10             True              True                  0.5  verified_purchase
# 11            False              True                  0.9  verified_purchase
# 12             True              True                  0.9  verified_purchase
# 13            False              True                  0.2    review_headline
# 14             True              True                  0.2    review_headline
# 15            False              True                  0.5    review_headline
# 16             True              True                  0.5    review_headline
# 17            False              True                  0.9    review_headline
# 18             True              True                  0.9    review_headline
#
#      roc_auc        f1
# 0   0.603607  0.601036
# 1   0.603790  0.597013
# 2   0.603576  0.592654
# 3   0.602218  0.595964
# 4   0.604042  0.586209
# 5   0.602094  0.587565
# 6   0.603908  0.598595
# 7   0.605108  0.588403
# 8   0.602626  0.587487
# 9   0.604989  0.600553
# 10  0.601782  0.590233
# 11  0.603212  0.592989
# 12  0.601240  0.597682
# 13  0.603531  0.595582
# 14  0.601053  0.567634
# 15  0.601623  0.587191
# 16  0.602288  0.585034
# 17  0.602760  0.585398
# 18  0.603468  0.593985

# %%
review_corruption_naive_exec_times = measure_review_corruption_naive_exec_time(debug=True,
                                                                               corruption_percentages=[0.2, 0.5, 0.9],
                                                                               corrupt_features=["star_rating", "verified_purchase", "review_headline"],
                                                                               repeats=30)
save_to_csv(review_corruption_naive_exec_times, "review_corruption_naive_exec_times")
review_corruption_naive_exec_times
# Out:
# No corruptions
# AUC Score on the test set: 0.613604105251665
# F1 Score on the test set: 0.6260728943959799
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6060786598895066
# F1 Score on the test set: 0.6020805149659008
# Corruptions in Train and test
# AUC Score on the test set: 0.5926843736001924
# F1 Score on the test set: 0.5351323119379441
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6002921695410791
# F1 Score on the test set: 0.5571184642942985
# Corruptions in Train and test
# AUC Score on the test set: 0.6042352772777071
# F1 Score on the test set: 0.6017337382941027
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6044151099469222
# F1 Score on the test set: 0.5910597574737422
# Corruptions in Train and test
# AUC Score on the test set: 0.6076833862082002
# F1 Score on the test set: 0.6105233494662472
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6033074656103834
# F1 Score on the test set: 0.59704744977414
# Corruptions in Train and test
# AUC Score on the test set: 0.6083837289716347
# F1 Score on the test set: 0.6106790639265759
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6029604914788596
# F1 Score on the test set: 0.5875832697961438
# Corruptions in Train and test
# AUC Score on the test set: 0.6020221128776145
# F1 Score on the test set: 0.5844875244912182
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.5985026789274697
# F1 Score on the test set: 0.5664676124736583
# Corruptions in Train and test
# AUC Score on the test set: 0.6009155703443531
# F1 Score on the test set: 0.5815813085737549
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6096752680905551
# F1 Score on the test set: 0.6168668086320828
# Corruptions in Train and test
# AUC Score on the test set: 0.6059280674192487
# F1 Score on the test set: 0.6004820274051875
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6032940828836424
# F1 Score on the test set: 0.5864919781170816
# Corruptions in Train and test
# AUC Score on the test set: 0.6046553232299812
# F1 Score on the test set: 0.5936939284007302
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6000488317369304
# F1 Score on the test set: 0.5684721687754699
# Corruptions in Train and test
# AUC Score on the test set: 0.5994735816892738
# F1 Score on the test set: 0.591834123172078
# Done!
# No corruptions
# AUC Score on the test set: 0.6011364726240545
# F1 Score on the test set: 0.5794804245658505
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.605492993570419
# F1 Score on the test set: 0.5987599170657478
# Corruptions in Train and test
# AUC Score on the test set: 0.600182219768084
# F1 Score on the test set: 0.5876528661471256
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6054894507249533
# F1 Score on the test set: 0.6031271055447663
# Corruptions in Train and test
# AUC Score on the test set: 0.605808812890849
# F1 Score on the test set: 0.5988748712089271
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6057749693767975
# F1 Score on the test set: 0.6002020709761737
# Corruptions in Train and test
# AUC Score on the test set: 0.6020359690298009
# F1 Score on the test set: 0.5880130440397779
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6046921298861154
# F1 Score on the test set: 0.6017205793924759
# Corruptions in Train and test
# AUC Score on the test set: 0.6098473996998452
# F1 Score on the test set: 0.6166192074924806
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6032378445434052
# F1 Score on the test set: 0.5826352965045003
# Corruptions in Train and test
# AUC Score on the test set: 0.6046356531099359
# F1 Score on the test set: 0.6039946571806247
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.5973759761081985
# F1 Score on the test set: 0.5630516802468941
# Corruptions in Train and test
# AUC Score on the test set: 0.6019796643452912
# F1 Score on the test set: 0.5772376990676719
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6041474720872515
# F1 Score on the test set: 0.5962535510274204
# Corruptions in Train and test
# AUC Score on the test set: 0.6037672886235677
# F1 Score on the test set: 0.6013164742457235
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.602408040030683
# F1 Score on the test set: 0.6013055738332661
# Corruptions in Train and test
# AUC Score on the test set: 0.6069261161731598
# F1 Score on the test set: 0.6099330839326363
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6040029568118166
# F1 Score on the test set: 0.6032866641496225
# Corruptions in Train and test
# AUC Score on the test set: 0.602908829321916
# F1 Score on the test set: 0.5908293290566091
# Done!
#     runtimes
# 0  83.718075
# 1  80.361686

# %%
# Other params hard-coded currently
# corruption_percentages=[0.2, 0.5, 0.9], corrupt_features=["star_rating", "verified_purchase", "review_headline"]
corruption_qualitative_review_corruption_opt = do_review_corruption_opt(debug=True)
save_to_csv(corruption_qualitative_review_corruption_opt, "corruption_qualitative_review_corruption_opt")
corruption_qualitative_review_corruption_opt
# Out:
# No corruptions
# AUC Score on the test set: 0.603382160604193
# F1 Score on the test set: 0.5809642249992473
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5934736404535061
# F1 Score on the test set: 0.5905188678017794
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5742269176999757
# F1 Score on the test set: 0.5815256446945849
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5748439606382916
# F1 Score on the test set: 0.5256818582805551
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.603382160604193
# F1 Score on the test set: 0.5809642249992473
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.603382160604193
# F1 Score on the test set: 0.5809642249992473
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.603382160604193
# F1 Score on the test set: 0.5809642249992473
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6027515025460514
# F1 Score on the test set: 0.5796047314671957
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5989358759661854
# F1 Score on the test set: 0.5704916303250572
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.597639324817244
# F1 Score on the test set: 0.5668051630577176
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5965330106619768
# F1 Score on the test set: 0.6010463008808585
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5979369687129387
# F1 Score on the test set: 0.5772448151023544
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.6009601783676155
# F1 Score on the test set: 0.5950222820967135
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6000023246175015
# F1 Score on the test set: 0.5609176207883511
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6056127961971736
# F1 Score on the test set: 0.6016747368622275
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6038474250818433
# F1 Score on the test set: 0.5915873940019927
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6068150908096006
# F1 Score on the test set: 0.6090918951050035
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6034958564030204
# F1 Score on the test set: 0.5831806363875395
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.5989410735740508
# F1 Score on the test set: 0.5719597967186107
#     test_corruption  train_corruption  corruption_fraction            feature  \
# 0             False             False                  NaN               None
# 1              True             False                  0.2        star_rating
# 2              True             False                  0.5        star_rating
# 3              True             False                  0.9        star_rating
# 4              True             False                  0.2  verified_purchase
# 5              True             False                  0.5  verified_purchase
# 6              True             False                  0.9  verified_purchase
# 7              True             False                  0.2    review_headline
# 8              True             False                  0.5    review_headline
# 9              True             False                  0.9    review_headline
# 10             True              True                  0.2        star_rating
# 11             True              True                  0.5        star_rating
# 12             True              True                  0.9        star_rating
# 13             True              True                  0.2  verified_purchase
# 14             True              True                  0.5  verified_purchase
# 15             True              True                  0.9  verified_purchase
# 16             True              True                  0.2    review_headline
# 17             True              True                  0.5    review_headline
# 18             True              True                  0.9    review_headline
#
#      roc_auc        f1
# 0   0.603382  0.580964
# 1   0.593474  0.590519
# 2   0.574227  0.581526
# 3   0.574844  0.525682
# 4   0.603382  0.580964
# 5   0.603382  0.580964
# 6   0.603382  0.580964
# 7   0.602752  0.579605
# 8   0.598936  0.570492
# 9   0.597639  0.566805
# 10  0.596533  0.601046
# 11  0.597937  0.577245
# 12  0.600960  0.595022
# 13  0.600002  0.560918
# 14  0.605613  0.601675
# 15  0.603847  0.591587
# 16  0.606815  0.609092
# 17  0.603496  0.583181
# 18  0.598941  0.571960

# %%
# Other params hard-coded currently
# corruption_percentages=[0.2, 0.5, 0.9], corrupt_features=["star_rating", "verified_purchase", "review_headline"]
review_corruption_opt_exec_times = measure_review_corruption_opt_exec_time(debug=True, repeats=30)
save_to_csv(review_corruption_opt_exec_times, "review_corruption_opt_exec_times")
review_corruption_opt_exec_times
# Out:
# No corruptions
# AUC Score on the test set: 0.6023376685745221
# F1 Score on the test set: 0.5979491715539302
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.590143285695653
# F1 Score on the test set: 0.5959639406898133
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5856502208125294
# F1 Score on the test set: 0.5932727146889538
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.6141319055873726
# F1 Score on the test set: 0.5338094556784942
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6023376685745221
# F1 Score on the test set: 0.5979491715539302
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6023376685745221
# F1 Score on the test set: 0.5979491715539302
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6023376685745221
# F1 Score on the test set: 0.5979491715539302
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6031203185151637
# F1 Score on the test set: 0.5984915810432797
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6008424064813437
# F1 Score on the test set: 0.593895836597395
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5980557639072508
# F1 Score on the test set: 0.5906145906638518
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.6002998521277179
# F1 Score on the test set: 0.59601120116503
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.595574446395769
# F1 Score on the test set: 0.5680863482194419
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.584405424593359
# F1 Score on the test set: 0.41852768626879977
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6035848602414082
# F1 Score on the test set: 0.5894085272010805
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6047027372459474
# F1 Score on the test set: 0.6021495861002953
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6067149821822873
# F1 Score on the test set: 0.6036438115779437
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.5992380786835854
# F1 Score on the test set: 0.586882124469629
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.604617338317915
# F1 Score on the test set: 0.5941426318380699
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.5999557904540944
# F1 Score on the test set: 0.5866675367411684
# Done!
# No corruptions
# AUC Score on the test set: 0.6069485962227217
# F1 Score on the test set: 0.5927233503511601
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5896305669065942
# F1 Score on the test set: 0.5894526949750056
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5835786393799052
# F1 Score on the test set: 0.5917254805412699
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Test
# AUC Score on the test set: 0.5813158769911564
# F1 Score on the test set: 0.5228291373553751
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6069485962227217
# F1 Score on the test set: 0.5927233503511601
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6069485962227217
# F1 Score on the test set: 0.5927233503511601
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Test
# AUC Score on the test set: 0.6069485962227217
# F1 Score on the test set: 0.5927233503511601
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6068539245769811
# F1 Score on the test set: 0.5907753227060157
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.6086809385470231
# F1 Score on the test set: 0.5938989769820971
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Test
# AUC Score on the test set: 0.5990168970814131
# F1 Score on the test set: 0.5782373352888257
# ____
# Now testing corruption of 20.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.596944839586323
# F1 Score on the test set: 0.5818181700720189
# ____
# Now testing corruption of 50.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5942943123841052
# F1 Score on the test set: 0.5793548012691361
# ____
# Now testing corruption of 90.0% of feature star_rating
# Corruptions in Train and Test
# AUC Score on the test set: 0.5992380786835854
# F1 Score on the test set: 0.586882124469629
# ____
# Now testing corruption of 20.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6038665080174515
# F1 Score on the test set: 0.6052177557044649
# ____
# Now testing corruption of 50.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6061667761809288
# F1 Score on the test set: 0.6069682236838435
# ____
# Now testing corruption of 90.0% of feature verified_purchase
# Corruptions in Train and Test
# AUC Score on the test set: 0.6036131427569833
# F1 Score on the test set: 0.5942616004565815
# ____
# Now testing corruption of 20.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6023882609301308
# F1 Score on the test set: 0.5683358251647443
# ____
# Now testing corruption of 50.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.6078714701321846
# F1 Score on the test set: 0.6064977509708739
# ____
# Now testing corruption of 90.0% of feature review_headline
# Corruptions in Train and Test
# AUC Score on the test set: 0.5979408954633809
# F1 Score on the test set: 0.5934987791554981
# Done!
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/stefanuva/Documents/deem-what-if-experiments/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#     runtimes
# 0  15.849788
# 1  15.284933
