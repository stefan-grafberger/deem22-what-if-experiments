# %%
from product_images_shapley_naive import print_legend, do_shapley_value_naive, measure_shapley_naive_exec_time
from whatif.experiments.product_images_shapley_opt import measure_shapley_opt_exec_time, do_shapley_value_opt
from whatif.experiments.product_images_shapley_qualitative import do_shapley_value_qualitative
from whatif.utils.utils import get_project_root
print_legend()

def save_to_csv(df, filename):
    df.to_csv(f'{str(get_project_root())}/whatif/experiments/datasets/sneakers/{filename}.csv',
              index=False)
# Out:
# iteration: In each iteration, we execute the pipeline and clean #cleaning_batch_size rows afterwards, either using shapley values or random sampling. Param for this: $use_shapley_weighting
# already_cleaned_rows: Already cleaned rows
# total_corrupted_rows: Total corrupted rows
# false_corruption_alarm: False alarms in that iteration for #rows that were not corrupted
# correct_corruption_alarm: Correct alarms in that iteration for #rows that were corrupted
# corruption_not_detected_yet: In that and previous iterations, there were corrupted #rows not discover yet
# fraction_data_cleaned: fraction of corrupted data that was cleaned already
# model_score: Model score on current data with potential left-over corruptions

# %%
shapley_qualitative_shapley_cleaning = do_shapley_value_qualitative(corruption_fraction=0.5,
                                                                    num_iterations=10,
                                                                    use_shapley_weighting=True,
                                                                    shapley_value_k=10,
                                                                    cleaning_batch_size=50)
save_to_csv(shapley_qualitative_shapley_cleaning, "shapley_qualitative_shapley_cleaning")
shapley_qualitative_shapley_cleaning
# Out:
# Starting iteration 0 now...
# ...
# 9/9 [==============================] - 0s 10ms/step - loss: 0.7280 - accuracy: 0.4710
# Starting iteration 1 now...
# ...
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6649 - accuracy: 0.9421
# Starting iteration 2 now...
# ...
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6486 - accuracy: 0.7683
# Starting iteration 3 now...
# ...
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5791 - accuracy: 0.9344
# Starting iteration 4 now...
# ...
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4095 - accuracy: 0.9305
# Starting iteration 5 now...
# ...
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3719 - accuracy: 0.9151
# Starting iteration 6 now...
# ...
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4006 - accuracy: 0.9073
# Starting iteration 7 now...
# ...
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2413 - accuracy: 0.9344
# Starting iteration 8 now...
# ...

# %%
shapley_qualitative_random_cleaning = do_shapley_value_qualitative(corruption_fraction=0.5,
                                                                   num_iterations=10,
                                                                   use_shapley_weighting=False,
                                                                   shapley_value_k=10,
                                                                   cleaning_batch_size=50)
save_to_csv(shapley_qualitative_random_cleaning, "shapley_qualitative_random_cleaning")
shapley_qualitative_random_cleaning
# Out:
# Starting iteration 0 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6976 - accuracy: 0.2348
# Starting iteration 1 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6876 - accuracy: 0.4652
# Starting iteration 2 now...
# ...
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6664 - accuracy: 0.8652
# Starting iteration 3 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6426 - accuracy: 0.8261
# Starting iteration 4 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6553 - accuracy: 0.8652
# Starting iteration 5 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6003 - accuracy: 0.9130
# Starting iteration 6 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5859 - accuracy: 0.9130
# Starting iteration 7 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5800 - accuracy: 0.9000
# Starting iteration 8 now...
# ...

# %%
shapley_performance_naive_w_model = measure_shapley_naive_exec_time(corruption_fraction=0.5,
                                                                    num_iterations=10,
                                                                    use_shapley_weighting=True,
                                                                    shapley_value_k=10,
                                                                    cleaning_batch_size=50,
                                                                    do_model_train_and_score=True,
                                                                    repeats=30)  # 30
save_to_csv(shapley_performance_naive_w_model, "shapley_performance_naive_w_model")
shapley_performance_naive_w_model
# Out:
# Starting iteration 0 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5070 - accuracy: 0.8025
# Starting iteration 1 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5261 - accuracy: 0.7857
# Starting iteration 2 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3992 - accuracy: 0.8529
# Starting iteration 3 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3922 - accuracy: 0.8403
# Starting iteration 4 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3179 - accuracy: 0.8697
# Starting iteration 5 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3234 - accuracy: 0.8613
# Starting iteration 6 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2338 - accuracy: 0.9034
# Starting iteration 7 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2771 - accuracy: 0.9034
# Starting iteration 8 now...
# ...

# %%
shapley_performance_naive_wo_model = measure_shapley_naive_exec_time(corruption_fraction=0.5,
                                                                     num_iterations=10,
                                                                     use_shapley_weighting=True,
                                                                     shapley_value_k=10,
                                                                     cleaning_batch_size=50,
                                                                     do_model_train_and_score=False,
                                                                     repeats=30)  # 30
save_to_csv(shapley_performance_naive_wo_model, "shapley_performance_naive_wo_model")
shapley_performance_naive_wo_model
# Out:
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
# Starting iteration 0 now...
# Starting iteration 1 now...
# ...

# %%
shapley_performance_opt_w_model = measure_shapley_opt_exec_time(corruption_fraction=0.5,
                                                                num_iterations=10,
                                                                use_shapley_weighting=True,
                                                                shapley_value_k=10,
                                                                cleaning_batch_size=50,
                                                                do_model_train_and_score=True,
                                                                repeats=30) # 30
save_to_csv(shapley_performance_opt_w_model, "shapley_performance_opt_w_model")
shapley_performance_opt_w_model
# Out:
# Starting iteration 0 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6220 - accuracy: 0.7143
# Starting iteration 1 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5437 - accuracy: 0.7437
# Starting iteration 2 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4668 - accuracy: 0.8109
# Starting iteration 3 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3690 - accuracy: 0.8655
# Starting iteration 4 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3280 - accuracy: 0.8697
# Starting iteration 5 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2794 - accuracy: 0.8908
# Starting iteration 6 now...
# ...
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2690 - accuracy: 0.9034
# Starting iteration 7 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1911 - accuracy: 0.9202
# Starting iteration 8 now...
# ...

# %%
shapley_performance_opt_wo_model = measure_shapley_opt_exec_time(corruption_fraction=0.5,
                                                                 num_iterations=10,
                                                                 use_shapley_weighting=True,
                                                                 shapley_value_k=10,
                                                                 cleaning_batch_size=50,
                                                                 do_model_train_and_score=False,
                                                                 repeats=30) # 30
save_to_csv(shapley_performance_opt_wo_model, "shapley_performance_opt_wo_model")
shapley_performance_opt_wo_model
# Out:
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
# Starting iteration 0 now...
# Starting iteration 1 now...
# ...

# %%
# Some cells purely to verify that opt doesnt break something
# Effectiveness (clean percentage per iteration) should be similar to naive baseline
shapley_opt_qualitative_control_w_model = do_shapley_value_opt(corruption_fraction=0.2,
                                                               num_iterations=10,
                                                               use_shapley_weighting=True,
                                                               shapley_value_k=10,
                                                               cleaning_batch_size=50,
                                                               do_model_train_and_score=True)
save_to_csv(shapley_opt_qualitative_control_w_model, "shapley_opt_qualitative_control_w_model")
shapley_opt_qualitative_control_w_model
# Out:
# Starting iteration 0 now...
# ...
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5939 - accuracy: 0.7395
# Starting iteration 1 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4784 - accuracy: 0.8151
# Starting iteration 2 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4939 - accuracy: 0.8067
# Starting iteration 3 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3706 - accuracy: 0.8655
# Starting iteration 4 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2985 - accuracy: 0.8992
# Starting iteration 5 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2668 - accuracy: 0.8866
# Starting iteration 6 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3053 - accuracy: 0.8866
# Starting iteration 7 now...
# ...
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1924 - accuracy: 0.9202
# Starting iteration 8 now...
# ...

# %%
shapley_opt_qualitative_control_wo_model = do_shapley_value_opt(corruption_fraction=0.2,
                                                                num_iterations=10,
                                                                use_shapley_weighting=True,
                                                                shapley_value_k=10,
                                                                cleaning_batch_size=50,
                                                                do_model_train_and_score=False)
save_to_csv(shapley_opt_qualitative_control_wo_model, "shapley_opt_qualitative_control_wo_model")
shapley_opt_qualitative_control_wo_model
# Out:
# Starting iteration 0 now...
# Starting iteration 1 now...
# Starting iteration 2 now...
# Starting iteration 3 now...
# Starting iteration 4 now...
# Starting iteration 5 now...
# Starting iteration 6 now...
# Starting iteration 7 now...
# Starting iteration 8 now...
# Starting iteration 9 now...
# Done!
#    iteration  already_cleaned_rows  total_corrupted_rows  \
# 0          0                     0                   238
# 1          1                    50                   238
# 2          2                    99                   238
# 3          3                   142                   238
# 4          4                   175                   238
# 5          5                   189                   238
# 6          6                   201                   238
# 7          7                   213                   238
# 8          8                   217                   238
# 9          9                   220                   238
#
# ...

# %%
shapley_opt_qualitative_control_naive_baseline = do_shapley_value_naive(corruption_fraction=0.2,
                                                                        num_iterations=10,
                                                                        use_shapley_weighting=True,
                                                                        shapley_value_k=10,
                                                                        cleaning_batch_size=50,
                                                                        do_model_train_and_score=True)
save_to_csv(shapley_opt_qualitative_control_naive_baseline, "shapley_opt_qualitative_control_naive_baseline")
shapley_opt_qualitative_control_naive_baseline
# Out:
# Starting iteration 0 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5637 - accuracy: 0.7437
# Starting iteration 1 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5162 - accuracy: 0.8109
# Starting iteration 2 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4893 - accuracy: 0.8109
# Starting iteration 3 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3659 - accuracy: 0.9034
# Starting iteration 4 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2705 - accuracy: 0.9034
# Starting iteration 5 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2559 - accuracy: 0.9118
# Starting iteration 6 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2333 - accuracy: 0.9118
# Starting iteration 7 now...
# ...
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1441 - accuracy: 0.9412
# Starting iteration 8 now...
# ...
